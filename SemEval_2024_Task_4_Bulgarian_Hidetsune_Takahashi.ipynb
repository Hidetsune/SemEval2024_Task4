# %% [markdown]
# <a href="https://colab.research.google.com/github/Hidetsune/SemEval2024_Task4/blob/main/SemEval_2024_Task_4_Bulgarian_Hidetsune_Takahashi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import and Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import json

# %%
import re

# %%
training_validation_data = pd.read_csv("/content/drive/MyDrive/SemEval Task4/task4_data_concat_extended5.csv") # task5_data_concat_extended4.csv   (CHANGE HERE)
training_validation_data
# Out:
#                                                     text  \
# 0       we're here to help! send us a dm with your em...
# 1      then   now  raise your hand if jill should res...
# 2       hello, this does not sound good.  can you dm ...
# 3       sorry for the delay, katie! we'd like to inve...
# 4      you should have to pass a drug test to receive...
# ...                                                  ...
# 20769  writing for facerook tio apoloigai td mlrldott...
# 20770   hey matthew, flight 783 is showing a late arr...
# 20771   if the permissions cannot be disabled, they m...
# 20772   isn't prime two day shipping supposed to be g...
# 20773  chosen by god backed by our military. surround...
#
#       propagandistic/non_propagandistic
# 0                    non_propagandistic
# 1                        propagandistic
# 2                    non_propagandistic
# 3                    non_propagandistic
# 4                        propagandistic
# ...                                 ...
# 20769                    propagandistic
# 20770                non_propagandistic
# 20771                non_propagandistic
# 20772                non_propagandistic
# 20773                    propagandistic
#
# [20774 rows x 2 columns]

# %%
# !pip install "spacy >= 3.0.6"
# !pip install "comet_ml>=3.31.19"
# !pip install datasets
# Out:
# Requirement already satisfied: spacy>=3.0.6 in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy>=3.0.6) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.6) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.6) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.0.6) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.0.6) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy>=3.0.6) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=3.0.6) (2.1.4)
# Collecting comet_ml>=3.31.19
#   Downloading comet_ml-3.37.0-py3-none-any.whl (599 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.4/599.4 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (4.19.2)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml>=3.31.19)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 17.7 MB/s eta 0:00:00
# Collecting requests-toolbelt>=0.8.0 (from comet_ml>=3.31.19)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (2.31.0)
# Collecting semantic-version>=2.8.0 (from comet_ml>=3.31.19)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting sentry-sdk>=1.1.0 (from comet_ml>=3.31.19)
#   Downloading sentry_sdk-1.39.2-py2.py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 15.0 MB/s eta 0:00:00
# Collecting simplejson (from comet_ml>=3.31.19)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (2.0.7)
# Collecting websocket-client<1.4.0,>=0.55.0 (from comet_ml>=3.31.19)
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (1.14.1)
# Collecting wurlitzer>=1.0.2 (from comet_ml>=3.31.19)
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Collecting everett[ini]<3.2.0,>=1.0.1 (from comet_ml>=3.31.19)
#   Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml>=3.31.19)
#   Downloading dulwich-0.21.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (514 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (13.7.0)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml>=3.31.19)
#   Downloading configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml>=3.31.19) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml>=3.31.19) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml>=3.31.19) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml>=3.31.19) (0.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml>=3.31.19) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml>=3.31.19) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml>=3.31.19) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml>=3.31.19) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml>=3.31.19) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml>=3.31.19) (0.1.2)
# Installing collected packages: everett, wurlitzer, websocket-client, simplejson, sentry-sdk, semantic-version, python-box, dulwich, configobj, requests-toolbelt, comet_ml
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.7.0
#     Uninstalling websocket-client-1.7.0:
#       Successfully uninstalled websocket-client-1.7.0
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# Successfully installed comet_ml-3.37.0 configobj-5.0.8 dulwich-0.21.7 everett-3.1.0 python-box-6.1.0 requests-toolbelt-1.0.0 semantic-version-2.10.0 sentry-sdk-1.39.2 simplejson-3.19.2 websocket-client-1.3.3 wurlitzer-3.0.3
# Collecting datasets
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: dill, multiprocess, datasets
# Successfully installed datasets-2.16.1 dill-0.3.7 multiprocess-0.70.15

# %%
from datasets import Dataset, Value, ClassLabel, Features  #added

# %%
from sklearn.model_selection import train_test_split

# %%
training_data, validation_data = train_test_split(training_validation_data, test_size=0.05, random_state=10)

# %%
dataset_train = Dataset.from_pandas(training_data)
dataset_val = Dataset.from_pandas(validation_data)

# %%
categories = ['propagandistic', 'non_propagandistic']

# %%
new_features = dataset_train.features.copy()

# %%
new_features['text'] = Value('large_string')
new_features['propagandistic/non_propagandistic'] = ClassLabel(names=['propagandistic', 'non_propagandistic'])

# %%
dataset_train = dataset_train.cast(new_features)
dataset_val = dataset_val.cast(new_features)
# Out:
# Casting the dataset:   0%|          | 0/19735 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/1039 [00:00<?, ? examples/s]

# %%
dataset_train.features
# Out:
# {'text': Value(dtype='large_string', id=None),
#  'propagandistic/non_propagandistic': ClassLabel(names=['propagandistic', 'non_propagandistic'], id=None),
#  '__index_level_0__': Value(dtype='int64', id=None)}

# %%
dataset_val.features
# Out:
# {'text': Value(dtype='large_string', id=None),
#  'propagandistic/non_propagandistic': ClassLabel(names=['propagandistic', 'non_propagandistic'], id=None),
#  '__index_level_0__': Value(dtype='int64', id=None)}

# %% [markdown]
# #Training

# %%
from typing import Set, List, Tuple
from spacy.tokens import DocBin
import spacy
from tqdm.auto import tqdm

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"

locale.getpreferredencoding = getpreferredencoding

# %%
def convert_spacy_dataset(dataset, target_file: str, labels):
  nlp = spacy.blank("en")
  db = DocBin()

  for item in tqdm(dataset):
    try:
      doc = nlp.make_doc(item["text"])
      doc.cats = {label: 0 for label in labels}
      doc.cats[labels[item["propagandistic/non_propagandistic"]]] = 1

      db.add(doc)
    except:
      continue

  db.to_disk(target_file)
  return db

# %%
dataset_val
# Out:
# Dataset({
#     features: ['text', 'propagandistic/non_propagandistic', '__index_level_0__'],
#     num_rows: 1039
# })

# %%
convert_spacy_dataset(dataset_train, "train_data.spacy", categories)
convert_spacy_dataset(dataset_val, "validation_data.spacy", categories)
# Out:
#   0%|          | 0/19735 [00:00<?, ?it/s]
#   0%|          | 0/1039 [00:00<?, ?it/s]

# %%
# !python -m spacy init config --lang en --pipeline textcat_multilabel comet_config.cfg  #training model
# Out:
# 2024-01-26 00:36:42.083401: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-26 00:36:42.083457: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-26 00:36:42.084612: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-26 00:36:43.119708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: en
# - Pipeline: textcat_multilabel
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# comet_config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train comet_config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
from spacy.cli.train import train as spacy_train

config_path = "comet_config.cfg"
output_model_path = "output_models/"

spacy_train(
    config_path,
    output_path=output_model_path,
    overrides={
        "paths.train": "train_data.spacy",
        "paths.dev": "validation_data.spacy",
    },
    use_gpu=0

)
# Out:
# ✔ Created output directory: output_models
# ℹ Saving to output directory: output_models
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['textcat_multilabel']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TEXTC...  CATS_SCORE  SCORE
# ---  ------  -------------  ----------  ------
#   0       0           0.25       63.18    0.63
#   0     200          43.20       91.73    0.92
#   0     400          30.59       93.52    0.94
#   0     600          28.42       95.08    0.95
#   0     800          23.64       96.15    0.96
#   0    1000          21.22       96.59    0.97
#   0    1200          18.56       96.97    0.97
#   0    1400          18.38       97.39    0.97
#   0    1600          16.18       97.67    0.98
#   1    1800          14.27       97.88    0.98
#   1    2000          12.48       98.07    0.98
#   1    2200          12.23       98.21    0.98
#   2    2400          11.11       98.38    0.98
#   2    2600           9.97       98.42    0.98
#   3    2800           9.00       98.54    0.99
#   3    3000           8.69       98.53    0.99
#   4    3200           8.36       98.58    0.99
#   4    3400           7.42       98.60    0.99
#   4    3600           7.65       98.63    0.99
#   5    3800           6.60       98.67    0.99
#   5    4000           6.79       98.73    0.99
#   6    4200           6.32       98.72    0.99
#   6    4400           6.10       98.75    0.99
#   7    4600           5.69       98.77    0.99
#   7    4800           5.64       98.73    0.99
#   8    5000           5.27       98.76    0.99
#   8    5200           5.05       98.81    0.99
#   9    5400           5.15       98.81    0.99
#   9    5600           4.72       98.82    0.99
#  10    5800           4.64       98.83    0.99
#  10    6000           4.55       98.84    0.99
#  10    6200           4.29       98.86    0.99
#  11    6400           3.93       98.85    0.99
#  11    6600           4.27       98.87    0.99
#  12    6800           3.96       98.84    0.99
#  12    7000           3.88       98.83    0.99
#  13    7200           3.80       98.83    0.99
#  13    7400           3.53       98.86    0.99
#  14    7600           3.49       98.83    0.99
#  14    7800           3.43       98.83    0.99
#  15    8000           3.32       98.83    0.99
#  15    8200           3.23       98.84    0.99
# ✔ Saved pipeline to output directory
# output_models/model-last

# %% [markdown]
# #Trial

# %%
trained_nlp = spacy.load("output_models/model-best/")

# %%
# !iconv -f UTF-8 -t ASCII dev_unlabeled.json
# Out:
# iconv: cannot open input file `dev_unlabeled.json': No such file or directory

# %%
json_open_trial = open("/content/drive/MyDrive/SemEval Task4/bg_subtask2b_test_unlabeled.json","r", encoding="utf-8")
json_load_trial = json.load(json_open_trial)

# %%
trial_data = json_load_trial
trial_data
# Out:
# [{'id': '1',
#   'text': 'Когато се събудиш след като цяла\nнощ си се ваксинирала против\nкоронавирус/I\n',
#   'image': 'bg_memes_1.png'},
#  {'id': 'bg_mk_memes_984',
#   'text': 'Какво има в Костя Копейкин: ACE\n\nКакво има в Кирил Петков:\n\n',
#   'image': 'bg_mk_memes_984.png'},
#  {'id': '4',
#   'text': 'КАК СЕ ЧУВСТВАТЕ?\nИЗВЕДНЪЖ УСЕТИХ\nНЕОБЯСНИМА НУЖДА\nДА СИ РЕГИСТРИРАМ WINDOWS-A\n',
#   'image': 'bg_memes_4.png'},
#  {'id': '41',
#   'text': 'НИКОГА НЕ СЪМ ВЯРВАЛ, ЧЕ ОНОВА\nНАЧАЛО НА ВИЦОВЕТЕ ЩЕ СЕ ОКАЖЕ ИСТИНА:\nБАЙ ГАНЬО БЪЛГАРИНА\nИ БАЙ ГАНЬО АМЕРИКАНЕЦА...\nimgflip.com\n',
#   'image': 'bg_memes_41.png'},
#  {'id': '49',
#   'text': 'i\n2 часа след ваксинацията\nPIK\n',
#   'image': 'bg_memes_49.png'},
#  {'id': '50',
#   'text': 'ПРЕДИ ВАКСИНАТА\nСЛЕДВАКСИНАТА\nimgflip.com\n',
#   'image': 'bg_memes_50.png'},
#  {'id': '52',
#   'text': 'ЕC: Няма повишение в броя на\nбежанците от Афганистан\n07.10.2021 | 00:41 мин. | Сваляне\n@meme_рartiq\nДинко от\nЯмбол:\n',
#   'image': 'bg_memes_52.png'},
#  {'id': '53',
#   'text': '7 победи на избори\nв една снимка\n@meme_partiq\n',
#   'image': 'bg_memes_53.png'},
#  {'id': 'bg_mk_memes_840',
#   'text': 'НЕ ЗНАМ ЗАЩО МЕ НАРИЧАТ КОПЕЙКИН.\n',
#   'image': 'bg_mk_memes_840.png'},
#  {'id': 'bg_mk_memes_841',
#   'text': 'Военна комисия в Евросъюза.\n\nЗапочнаха набиране на\nдоброволци за война с Русия...\n',
#   'image': 'bg_mk_memes_841.png'},
#  {'id': 'bg_mk_memes_845',
#   'text': 'Тази вечер по залез слънце всички се молете\nДева Мария да спре войната в Украйна.\nПапата ще посвети Украйна и Русия на\nбезукорното сърце на Богородица!\n\nСподели, сподели,\nсподели .....\n',
#   'image': 'bg_mk_memes_845.png'},
#  {'id': 'bg_mk_memes_846',
#   'text': '!!! ОСТАВКА !!! НА "ЗЕЛЕНИЯ" АНТИ-ЕКО МИНИСТЪР\n\n',
#   'image': 'bg_mk_memes_846.png'},
#  {'id': 'bg_mk_memes_847',
#   'text': 'Министърът на отбраната в Италия\nвстъпва в длъжност!\nДа й пожелаем успех !\n\nНовый министр обороны Италии вступает в\nдолжность\n',
#   'image': 'bg_mk_memes_847.png'},
#  {'id': 'bg_mk_memes_848',
#   'text': 'МИШЕЛ ОТ СЪПРОТИВАТА\nРУСКИТЕ ШПИОНИ ВЪВ ФИЛМИТЕ\n\nРУСКИТЕ ШПИОНИ В ДЕЙСТВИТЕЛНОСТ\n',
#   'image': 'bg_mk_memes_848.png'},
#  {'id': 'bg_mk_memes_849',
#   'text': 'Неутралитет за България.Ние сме братя\nис руския народ и с украинския народ!\n',
#   'image': 'bg_mk_memes_849.png'},
#  {'id': 'bg_mk_memes_866',
#   'text': 'БЪЛГАРСКИЯТ НАРОД\nСЕ РАЗГРАНИЧАВА ОТ\nПРОДАЖНИТЕ ПОЛИТИЦИ!\nИСКАМЕ МИР С РУСИЯ\nИ БЪЛГАРИЯ - ВЪН ОТ\nФАШИСТКИТЕ МАФИИ!!\n',
#   'image': 'bg_mk_memes_866.png'},
#  {'id': 'bg_mk_memes_867',
#   'text': 'Платих на Америка\nедно време едни милиарди\nза едни изтребители!\n\nАми къде са, когато ни трябват?!\n',
#   'image': 'bg_mk_memes_867.png'},
#  {'id': 'bg_mk_memes_869', 'text': 'NATO', 'image': 'bg_mk_memes_869.png'},
#  {'id': 'bg_mk_memes_870',
#   'text': "As a BBC-funded journalist I have to\nremain consistently politically neutral.\nSo here's a photo of some flowers on a\nsunny day.\n",
#   'image': 'bg_mk_memes_870.png'},
#  {'id': 'bg_mk_memes_871',
#   'text': 'ЭТО НАШИ ДРУЗЬЯ!\n',
#   'image': 'bg_mk_memes_871.png'},
#  {'id': 'bg_mk_memes_872',
#   'text': 'Polish moms left strollers at a train\nstation for Ukrainian moms who may need them when they arrive in Poland with kids\n',
#   'image': 'bg_mk_memes_872.png'},
#  {'id': 'bg_mk_memes_987',
#   'text': 'Видиш ли зор,\nзапали Беломор!\n',
#   'image': 'bg_mk_memes_987.png'},
#  {'id': 'bg_mk_memes_989',
#   'text': 'ДРУЖБА ОТ ВЕКОВЕ- ЗА ВЕКОВЕ!\n\nБЪЛГАРИЯ И РУСИЯ\n\n',
#   'image': 'bg_mk_memes_989.png'},
#  {'id': '38',
#   'text': 'Coronavirus\nCOVID-19\nВаксината\n',
#   'image': 'bg_memes_38.png'},
#  {'id': '39',
#   'text': '"Ако не си бяхме\nразвалили\nОТношенията с\nРусия, нямаше да\nНи Споделят\nТОЛКова беди.\nГоспод ни наказва\nза нашата\nнеблагодарносТ\nкЪм нея -нашата\nОСвободителка."\n16\nСА\nВанга\n',
#   'image': 'bg_memes_39.png'},
#  {'id': '40',
#   'text': 'НЯМА ИЗВЪНРЕДНО\nПОЛОЖЕНИЕ\n',
#   'image': 'bg_memes_40.png'},
#  {'id': '42',
#   'text': 'Забавен Тъжен Ядосан\nЗабавен Тъжен Ядосан\nЗабавен Тъжен\nЯдосан\nSTARECAT.COM\nЗабавен Тъжен\nЯдосан\n',
#   'image': 'bg_memes_42.png'},
#  {'id': '43', 'text': 'ПРЕДИ И СЛЕД\nВАКСИНАТА\n', 'image': 'bg_memes_43.png'},
#  {'id': '44', 'text': '2D2M\n22i\n2022\n7.\n', 'image': 'bg_memes_44.png'},
#  {'id': '45',
#   'text': 'Да, подкрепям ПППП\nПЕТИЛЕТКАТА ЗА\nЧЕТИРИ ГОДИНИ\nANCH\nПролетариата\nПетилетката\nПети интернационал\nПалави котенца.\n',
#   'image': 'bg_memes_45.png'},
#  {'id': '47',
#   'text': 'Моля Ви,\nуспокойте се!\nНе сме дошли\nNOVANEWS\nтук да правим\nциркове!\nL GGG\n',
#   'image': 'bg_memes_47.png'},
#  {'id': '48',
#   'text': 'Очаквам кукери в министерски съвет през\nфевруари\nAFP\nМеждувременно В САЩ:\nPOL\n8YA6W8\nSaul Loeb/AFP\n',
#   'image': 'bg_memes_48.png'},
#  {'id': '5', 'text': 'istoricheski_humor\nВЕТО\n', 'image': 'bg_memes_5.png'},
#  {'id': '12',
#   'text': 'Слави: Ще изпратим в Космоса\nжена, мъж и един македонец\nПартиите на протеста:\nMисия 121\nimgflip.com\n',
#   'image': 'bg_memes_12.png'},
#  {'id': '13',
#   'text': 'КОГАТО КАЗВАТ ЧЕ ДОБРОТО\nВИНАГИ ПОБЕЖДАВАЛО, АМА СЕ СЕТИШ\nКОЙ ПОБЕДИ ПРЕЗ ВТОРАТА СВЕТОВНА ВОЙНА:\nTerezpro Bzarapcko 1lapergo\nimgflip.com\n',
#   'image': 'bg_memes_13.png'},
#  {'id': '15',
#   'text': "Ol istoricheski_humor\nHOW IT STARTED\nLIVE KABUL\nAL JAZEERA EXCLUSIVE\nHOW IT'S GOING\nimof.com\n",
#   'image': 'bg_memes_15.png'},
#  {'id': '18',
#   'text': 'САЩ\nТАЛИБАНИТЕ\n2001\nYerrzpTo Bzarapoko LļaperBo\nТАЛИБАНИТЕ\n2021\nimgflip.com\n',
#   'image': 'bg_memes_18.png'},
#  {'id': '19',
#   'text': 'САЩ\nТАЛИБАНИТЕ\n2001\nYerrzpTo Bzarapoko LļaperBo\nТАЛИБАНИТЕ\n2021\nimgflip.com\n',
#   'image': 'bg_memes_19.png'},
#  {'id': '20',
#   'text': 'комунистите са\nотровили борис три\nнемците са\nотровили борис три\n',
#   'image': 'bg_memes_20.png'},
#  {'id': '21',
#   'text': 'Хаос след изтеглянето на американските сили\nи превземането на Сойфия от моджохидините.\n(Летище Сойфия, 2021г., оцветено)\nБ AIR FORCЕ\n1109\nAMERICA FOR\n62 AW\nBULGARIA\n446 AW\nFOUNDATтION\nTEPMMNAA2 PT AL 2\n',
#   'image': 'bg_memes_21.png'},
#  {'id': '22',
#   'text': 'Какво съдържа ваксината\n"Pfizer"!\nна Бил Гейтс\nЛитий Потиска волята\nи желанието за борба.\nБарий Предизвиква рак\nстерилитети левкимия\nЖивак Убива имунната\nсистема и чер. кр. телца\nАлуминий Предизвиква\nрак и тромб във вените\nАнтифриз Унищожава\n\'мозъчните клетки\nОЩЕ ЛИ ИСКАТЕ ДА\n20\nm СЕ ВАКСИНИРАТЕ ?\n',
#   'image': 'bg_memes_22.png'},
#  {'id': '23',
#   'text': 'Американьо, документи\nза проверка\nНямате право\nUN\nIN\nDONT TREAD ON ME\nGRIY SLOA\nNEMORIA\nHOSPITAL\nГаньо, документи за\nпроверка\nUN\nCOVID\nLIGMA\nvariont\n',
#   'image': 'bg_memes_23.png'},
#  {'id': '24',
#   'text': 'Демократичнг))\nБългария\nОБЕДИНЕНИЕ\nДемократична\nБългария\nИскам да живея\nв нормална\nдържава\nДемократична\nБългария\nОБЕДИНЕНИЕ\nEEEEEL\nДемократична\nБългария\nОБЕДИНЕН ИЕ\n',
#   'image': 'bg_memes_24.png'},
#  {'id': 'bg_mk_memes_934',
#   'text': 'Откриха руски нефт в наши води!\n\n',
#   'image': 'bg_mk_memes_934.png'},
#  {'id': 'bg_mk_memes_942',
#   'text': 'Подготвка за унищожаването на НАТО!\n',
#   'image': 'bg_mk_memes_942.png'},
#  {'id': 'bg_mk_memes_943',
#   'text': '"Да бъде проклета оная\nминута, когато е стъпил\nруски крак в нашата земя."\nЗахари Стоянов\n\n"Русия не идва да ни\nосвободи, а да ни пороби,\nзавладее и погълне."\nСтефан Стамболов\n\n"Длъжност свята към милото ни\nотечество налага ни да открием\nкакво нещо е тая Русия и нейното\nмъчителско правителство."\nГеорги Раковски\n',
#   'image': 'bg_mk_memes_943.png'},
#  {'id': 'bg_mk_memes_944',
#   'text': 'НАЙ-ГОЛЕМИЯТ УЖАС ЗА РУСИЯ:\nАКТЬОР, КОЙТОЕ СТАНАЛ ПРЕЗИДЕНТ\n',
#   'image': 'bg_mk_memes_944.png'},
#  {'id': 'bg_mk_memes_945',
#   'text': 'Как върви\nс Русия,\nобяви ли\nим война\n\nОще не, но\nработя по\nвъпроса\n\nТоя е по-добър\nот Зеленски\n',
#   'image': 'bg_mk_memes_945.png'},
#  {'id': 'bg_mk_memes_946',
#   'text': 'А Bue kЪgЕ бЯХmE, kОГamO на\nkueBckuя кмет брат му биеше\nбеззащитни българи?\n',
#   'image': 'bg_mk_memes_946.png'},
#  {'id': 'bg_mk_memes_947',
#   'text': 'AUDI Q7 HA\nИЗТОЧНИЯ БЛОК\n',
#   'image': 'bg_mk_memes_947.png'},
#  {'id': 'bg_mk_memes_948',
#   'text': 'Кат РуZия няма вто...\nМлък!\n\n',
#   'image': 'bg_mk_memes_948.png'},
#  {'id': 'bg_mk_memes_950',
#   'text': 'Ало, Уил Смит? Чухте ли какво каза\nПутин за жена ви?\n',
#   'image': 'bg_mk_memes_950.png'},
#  {'id': 'bg_mk_memes_953',
#   'text': 'МНОГО газ\nСело в Путинска Русия\n\nбез газ\nСело в джендърския ЕС/ Германия\n',
#   'image': 'bg_mk_memes_953.png'},
#  {'id': '64',
#   'text': 'Македония опитваща се да\nпродължи преговорите за\nвлизане в ЕС, 2021г(оцветено)\nRo\nimaflip.com\n',
#   'image': 'bg_memes_64.png'},
#  {'id': '65',
#   'text': 'i\nbgnes.bg\nПредседателят на Македонската академия:\nРСМ е била под 100 години българско робство\n',
#   'image': 'bg_memes_65.png'},
#  {'id': '66',
#   'text': 'Македонците, когато\nзапочнат да разказват за\n"великата" си история\n@meme_partiq\n',
#   'image': 'bg_memes_66.png'},
#  {'id': '67',
#   'text': 'Аз: Няма да говоря за политика\nСъщо аз, след третата ракия:\n@meme рartiq\n',
#   'image': 'bg_memes_67.png'},
#  {'id': '68',
#   'text': '@meme_partiq\nЦирк\nМного по-голям Цирк\n',
#   'image': 'bg_memes_68.png'},
#  {'id': '69',
#   'text': 'С тази шега албанският премиер Еди Рама\nсе обърна към македонския си колега\nЗоран Заев на икономическия форум в\nСкопие.\nДНЕВНИК bg\ndnevnik.bg\nЦитат на деня: Дано не поискат да се\nнаречете Западна България\n',
#   'image': 'bg_memes_69.png'},
#  {'id': '75',
#   'text': 'Никога не е била!\nЧакай, Земята не\nе македонска?\n',
#   'image': 'bg_memes_75.png'},
#  {'id': 'bg_mk_memes_952',
#   'text': 'Неутралитет за\nБългария.Ние сме братя\nи с руския народ и с\nукраинския народ!\n',
#   'image': 'bg_mk_memes_952.png'},
#  {'id': 'bg_mk_memes_954',
#   'text': 'Каква е\nситуацията в\nСофия,\nбългаритее\nвоюват ли с,\nнас\n\nСъдейки, по начина по\nкойто купуват олио.\nПетков трябва да е луд,\nда им даде оръжие\n\nИ ако все пак им,\nдаде\n\nПоловината ще\nстрелят по политици,\nдругата половина по\nпосолството на САЩ\n',
#   'image': 'bg_mk_memes_954.png'},
#  {'id': 'bg_mk_memes_956',
#   'text': 'Ще се откажем от менделеевата таблица,\nзащото е изобретена от руснак - Дмитрий\nИванович Менделеев!\n',
#   'image': 'bg_mk_memes_956.png'},
#  {'id': 'bg_mk_memes_958',
#   'text': 'Ако Путин нападне страна от\nНАТО, веднага ще изхвърля\nтази страна от НАТО\n',
#   'image': 'bg_mk_memes_958.png'},
#  {'id': 'bg_mk_memes_960',
#   'text': 'АЗ СЪМ\nПРОТИВ NАТО И\nРАЗПОЛАГАНЕТО НА\nВОЙСКИ В БЪЛГАРИЯ\nРЕАCE\n',
#   'image': 'bg_mk_memes_960.png'},
#  {'id': 'bg_mk_memes_961',
#   'text': 'Байдън сподели мнението си за\nруската хиперзвукова ракета\n.Кинжал ": .Това е като всяка друга\nракета. Тя е почти неудържима.\n"Тя има същата бойна глава\nкато всяка друга ракета. Няма\nголяма разлика, освен че е почти\nневъзможно да се спре"\n\n',
#   'image': 'bg_mk_memes_961.png'},
#  {'id': 'bg_mk_memes_962',
#   'text': 'Има бежанци и бежанци!\nЕдните са хора, а другите не са ли?\n\nUkraine\nMuslims\n\n',
#   'image': 'bg_mk_memes_962.png'},
#  {'id': 'bg_mk_memes_963',
#   'text': 'почакай къде хукна,\nне съм ти дал мозък\n\nНЕ МОГА...ТРЯБВА ДА\nКОМЕНТИРАМ\nсЪБитиятА и войната\nв УКРАЙНА\n',
#   'image': 'bg_mk_memes_963.png'},
#  {'id': 'bg_mk_memes_964',
#   'text': 'ЩА €бна у кокошката !\n',
#   'image': 'bg_mk_memes_964.png'},
#  {'id': 'bg_mk_memes_965',
#   'text': 'НЕКА БЪЛГАРСКИЯТ НАРОД\nДА НЕ ЗАБРАВЯ НИКОГА,\nЧЕ ДЪЛЖИ СВОБОДАТА СИ\nНА СВОИТЕ РУСКИ БРАТЯ,\nДАЛИ ЖИВОТА СИ ЗА НЕЯ!\n',
#   'image': 'bg_mk_memes_965.png'},
#  {'id': 'bg_mk_memes_966',
#   'text': 'БЪЛГАРИ!\nНа 03.03, като празнувате Освобождението\nна България оТ Турско робство,\nхубаво си спомнете, кой виосвободи!\n',
#   'image': 'bg_mk_memes_966.png'},
#  {'id': 'bg_mk_memes_375',
#   'text': 'М3: Навсякъде ще се влиза със зелен сертификат\n\nBest l can do is kpаш на системата ',
#   'image': 'bg_mk_memes_375.png'},
#  {'id': 'bg_memes_468',
#   'text': 'Отворете бузки...\n',
#   'image': 'bg_memes_468.png'},
#  {'id': 'bg_memes_498', 'text': 'ПАНДЕМИЯ\n', 'image': 'bg_memes_498.png'},
#  {'id': 'bg_memes_500',
#   'text': 'Динко от Ямбол: Изкарвам танка, ако Русия ни застраши\n',
#   'image': 'bg_memes_500.png'},
#  {'id': 'bg_memes_507',
#   'text': 'БУЛГАРСКИИ РАМ БОСИЛЕК\n\nкто он?\n',
#   'image': 'bg_memes_507.png'},
#  {'id': 'bg_memes_508',
#   'text': 'коврид\nковрид\nковрид\n\nмедии\n\nКоврид!\nУкрайна\nКлик\n\nУкрайна\nУкрайна\nУкрайна\nУкрайна\n',
#   'image': 'bg_memes_508.png'},
#  {'id': 'bg_memes_447',
#   'text': 'Путин усложнява изпитите по география\n',
#   'image': 'bg_memes_447.png'},
#  {'id': 'bg_mk_memes_826',
#   'text': 'Руски танк, видял Байрактар, се\nпреструва на умрел...\n',
#   'image': 'bg_mk_memes_826.png'},
#  {'id': 'bg_mk_memes_827',
#   'text': 'КОПЕЙКИН СЪС СЕГАШНИЯ КУРС НА РУБЛАТА\n\n',
#   'image': 'bg_mk_memes_827.png'},
#  {'id': 'bg_mk_memes_828',
#   'text': 'И двамата са от ВгъзРаждани\n',
#   'image': 'bg_mk_memes_828.png'},
#  {'id': 'bg_mk_memes_829',
#   'text': 'почакай къде хукна,\nне съм ти дал мозък\n\nНЕ МОГА...ТРЯБВА ДА\nКОМЕНТИРАМ\nСЪБИТИЯТА и ВОЙНАТА\nВ УКРАЙНА\n',
#   'image': 'bg_mk_memes_829.png'},
#  {'id': 'bg_mk_memes_830',
#   'text': 'А Bue kЪgЕ бЯХmE, kОГamO на\nkueBckuя кмет брат му биеше\nбеззащитни българи?\n\n',
#   'image': 'bg_mk_memes_830.png'},
#  {'id': 'bg_mk_memes_831',
#   'text': 'Украинка учи чичо Ахмет,\nда говори Украински.\n\nКак тебя завут ?\nЯ тебя, иска да ашладисва.\n',
#   'image': 'bg_mk_memes_831.png'},
#  {'id': 'bg_mk_memes_832',
#   'text': 'Тази чешма от 1762г. в центъра\nна Габрово е с 14 години\n"по-голяма" от САЩ\n',
#   'image': 'bg_mk_memes_832.png'},
#  {'id': 'bg_mk_memes_833',
#   'text': 'АЗ СЪМ ИЗУМРУДЕНИЯТ\nДРАКОН! САМО ВЪЗРАЖДАНЕ\nИ СВЕТИ ВЛАСТЕЛИН\nВЪЗРОДИТЕЛ!\n\nСПАСИТЕЛЯТ НА БЪЛГАРИЯ!\n\nКоце, пий си хапчетата\n',
#   'image': 'bg_mk_memes_833.png'},
#  {'id': 'bg_mk_memes_834',
#   'text': 'КОЙ АРЕСТ Е\nУНИЗИТЕЛЕН?\n\n12 секунди\nна показ\n\n12 ЧАСА\nна показ с белезници зад\nгърба, без вода, тоалетна,\nпред медиите и\nобществото\n\n',
#   'image': 'bg_mk_memes_834.png'},
#  {'id': '76',
#   'text': 'Тате Тате || даа\nАз съм\nМакедонфц\nthe\nЩе гориш на клада\nти атеист такъв\n',
#   'image': 'bg_memes_76.png'},
#  {'id': '8',
#   'text': 'МАКЕДОНИЯ и\nБЪЛГАРИЯ\nМАКЕДОНИЯ и\n- БЪЛГАРИЯ\nМОГАТ ДА СЕ РАЗБЕРАТ МОГАТ ДА СЕ РАЗБЕРАТ\nИ ДА СА В ХАРМОНИЯ\nИ ДА СА В ХАРМОНИЯ\nМАКЕДОНИЯИ БЪЛГАРИЯ\nМОГАТ ДА СЕ РАЗБЕРАТ\nИ ДА СА В ХАРМОНИЯ\nМАКЕДОНИЯЕ\nБЪЛГАРСКА!!!\n',
#   'image': 'bg_memes_8.png'},
#  {'id': '9',
#   'text': 'АМЕРИКАНСКАТА МЕЧТА\nglasspar\nDoughboy\nCHATIES\nChiemen\nRayai Chaf\nБЪЛГАРСКАТА МЕЧТА\nHA\nКрушевац\nРазград\nДобрич\nФердинанд\nПлевен\nШумен\nНиш\nВарна\nН. пазар\nПирот\nВраца\nТьрново\nК. Митровица\nГаброво\nСОФИЯ\nСливен\nПрищина\nПерник\nЧерно море\n. Враня\nСтара Загора\nЯмбол\nБургася\nКюстендил\nПризрен,\nПазарджик\nПловдив\nКукъс\n.Куманово\nТетово\nСкопие\nГорна Джумая\nХасково\nВелес\nЩип\nОдрин\nЛозенград\nКърджали\nНеврокоп\nСмолян\n.Дебър\nСтрумица\nЛюлебургас\nПрилеп\nСтруго\nОхрид\nБитоля\nДрама\nКсанти гюмюрджина\nИстанбул\nРодосто\nКукуш\nКавала\nДедеајач\nЛерин\nВоден\nМраморно море\nКорча\nСолун\nостур\nСамотраки\nГалилоли\nКожани\nКатерини\nБяло море\nГревена\n.Чанаккале\n',
#   'image': 'bg_memes_9.png'},
#  {'id': 'bg_mk_memes_990',
#   'text': 'От днес обявяваме koд "Червено" за цялата страна..',
#   'image': 'bg_mk_memes_990.png'},
#  {'id': 'bg_mk_memes_992',
#   'text': 'усещам миризмата на сърми',
#   'image': 'bg_mk_memes_992.png'},
#  {'id': 'bg_mk_memes_993',
#   'text': 'СЛЕД ЧЕРНИЯ ПЕТЪК, ДОЙДЕ БЕЛИЯТ СНЯГ',
#   'image': 'bg_mk_memes_993.png'},
#  {'id': 'bg_mk_memes_995',
#   'text': 'Успях! Още 3 кила и съм на нула.',
#   'image': 'bg_mk_memes_995.png'},
#  {'id': 'bg_mk_memes_997',
#   'text': 'Коги намериш някой вечно недоволен като теб.\nНе е красиво.\nИ на мен не ми харесва.',
#   'image': 'bg_mk_memes_997.png'},
#  {'id': 'bg_mk_memes_998',
#   'text': 'Понякога просто трябва да оставим проблемите зад себе си.',
#   'image': 'bg_mk_memes_998.png'},
#  {'id': 'bg_mk_memes_999',
#   'text': 'Пътна инфраструктура Ви пожелава "Обичайте се"',
#   'image': 'bg_mk_memes_999.png'},
#  {'id': 'bg_mk_memes_1005',
#   'text': 'ТЕТРИС ЗА 40+ ГОДИШНИ',
#   'image': 'bg_mk_memes_1005.png'},
#  {'id': 'bg_mk_memes_1010',
#   'text': 'Но мамо, училището отваря след 6 дни?!\nНяма проблем. Ходете бавно!',
#   'image': 'bg_mk_memes_1010.png'},
#  {'id': 'bg_mk_memes_1024',
#   'text': 'половин бутилка\nАвера който не е давал пари щото е болен и няма да пие\nАЗ',
#   'image': 'bg_mk_memes_1024.png'}]

# %%
# !pip install -U deep-translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (4.11.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2023.11.17)
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4

# %%
from deep_translator import GoogleTranslator

# %%
langs_dict = GoogleTranslator().get_supported_languages(as_dict=True)
langs_dict
# Out:
# {'afrikaans': 'af',
#  'albanian': 'sq',
#  'amharic': 'am',
#  'arabic': 'ar',
#  'armenian': 'hy',
#  'assamese': 'as',
#  'aymara': 'ay',
#  'azerbaijani': 'az',
#  'bambara': 'bm',
#  'basque': 'eu',
#  'belarusian': 'be',
#  'bengali': 'bn',
#  'bhojpuri': 'bho',
#  'bosnian': 'bs',
#  'bulgarian': 'bg',
#  'catalan': 'ca',
#  'cebuano': 'ceb',
#  'chichewa': 'ny',
#  'chinese (simplified)': 'zh-CN',
#  'chinese (traditional)': 'zh-TW',
#  'corsican': 'co',
#  'croatian': 'hr',
#  'czech': 'cs',
#  'danish': 'da',
#  'dhivehi': 'dv',
#  'dogri': 'doi',
#  'dutch': 'nl',
#  'english': 'en',
#  'esperanto': 'eo',
#  'estonian': 'et',
#  'ewe': 'ee',
#  'filipino': 'tl',
#  'finnish': 'fi',
#  'french': 'fr',
#  'frisian': 'fy',
#  'galician': 'gl',
#  'georgian': 'ka',
#  'german': 'de',
#  'greek': 'el',
#  'guarani': 'gn',
#  'gujarati': 'gu',
#  'haitian creole': 'ht',
#  'hausa': 'ha',
#  'hawaiian': 'haw',
#  'hebrew': 'iw',
#  'hindi': 'hi',
#  'hmong': 'hmn',
#  'hungarian': 'hu',
#  'icelandic': 'is',
#  'igbo': 'ig',
#  'ilocano': 'ilo',
#  'indonesian': 'id',
#  'irish': 'ga',
#  'italian': 'it',
#  'japanese': 'ja',
#  'javanese': 'jw',
#  'kannada': 'kn',
#  'kazakh': 'kk',
#  'khmer': 'km',
#  'kinyarwanda': 'rw',
#  'konkani': 'gom',
#  'korean': 'ko',
#  'krio': 'kri',
#  'kurdish (kurmanji)': 'ku',
#  'kurdish (sorani)': 'ckb',
#  'kyrgyz': 'ky',
#  'lao': 'lo',
#  'latin': 'la',
#  'latvian': 'lv',
#  'lingala': 'ln',
#  'lithuanian': 'lt',
#  'luganda': 'lg',
#  'luxembourgish': 'lb',
#  'macedonian': 'mk',
#  'maithili': 'mai',
#  'malagasy': 'mg',
#  'malay': 'ms',
#  'malayalam': 'ml',
#  'maltese': 'mt',
#  'maori': 'mi',
#  'marathi': 'mr',
#  'meiteilon (manipuri)': 'mni-Mtei',
#  'mizo': 'lus',
#  'mongolian': 'mn',
#  'myanmar': 'my',
#  'nepali': 'ne',
#  'norwegian': 'no',
#  'odia (oriya)': 'or',
#  'oromo': 'om',
#  'pashto': 'ps',
#  'persian': 'fa',
#  'polish': 'pl',
#  'portuguese': 'pt',
#  'punjabi': 'pa',
#  'quechua': 'qu',
#  'romanian': 'ro',
#  'russian': 'ru',
#  'samoan': 'sm',
#  'sanskrit': 'sa',
#  'scots gaelic': 'gd',
#  'sepedi': 'nso',
#  'serbian': 'sr',
#  'sesotho': 'st',
#  'shona': 'sn',
#  'sindhi': 'sd',
#  'sinhala': 'si',
#  'slovak': 'sk',
#  'slovenian': 'sl',
#  'somali': 'so',
#  'spanish': 'es',
#  'sundanese': 'su',
#  'swahili': 'sw',
#  'swedish': 'sv',
#  'tajik': 'tg',
#  'tamil': 'ta',
#  'tatar': 'tt',
#  'telugu': 'te',
#  'thai': 'th',
#  'tigrinya': 'ti',
#  'tsonga': 'ts',
#  'turkish': 'tr',
#  'turkmen': 'tk',
#  'twi': 'ak',
#  'ukrainian': 'uk',
#  'urdu': 'ur',
#  'uyghur': 'ug',
#  'uzbek': 'uz',
#  'vietnamese': 'vi',
#  'welsh': 'cy',
#  'xhosa': 'xh',
#  'yiddish': 'yi',
#  'yoruba': 'yo',
#  'zulu': 'zu'}

# %%
for utterance in trial_data:
  utterance["text"] = GoogleTranslator(source='bg', target='en').translate(utterance["text"])

# %%
trial_data
# Out:
# [{'id': '1',
#   'text': 'When you wake up after being healed\nnight you got vaccinated against\ncoronavirus/I',
#   'image': 'bg_memes_1.png'},
#  {'id': 'bg_mk_memes_984',
#   'text': "What's in Kostya Kopeikin: ACE\n\nWhat's in Kiril Petkov:",
#   'image': 'bg_mk_memes_984.png'},
#  {'id': '4',
#   'text': 'HOW DO YOU FEEL?\nSUDDENLY I FELT\nAN UNEXPLAINABLE NEED\nTO REGISTER WINDOWS-A',
#   'image': 'bg_memes_4.png'},
#  {'id': '41',
#   'text': 'I NEVER BELIEVED THAT\nTHE BEGINNING OF THE JOKES WILL TURN OUT TO BE TRUE:\nBYE GANYO BULGARINA\nAND BYE GANYO THE AMERICAN...\nimgflip.com',
#   'image': 'bg_memes_41.png'},
#  {'id': '49',
#   'text': 'i\n2 hours after vaccination\nPIK',
#   'image': 'bg_memes_49.png'},
#  {'id': '50',
#   'text': 'BEFORE THE VACCINE\nTHE POST-VACCINE\nimgflip.com',
#   'image': 'bg_memes_50.png'},
#  {'id': '52',
#   'text': 'EC: No increase in the number of\nrefugees from Afghanistan\n07.10.2021 | 00:41 min | Download\n@meme_рartiq\nDinko from\nYambol:',
#   'image': 'bg_memes_52.png'},
#  {'id': '53',
#   'text': '7 election victories\nin one photo\n@meme_partiq',
#   'image': 'bg_memes_53.png'},
#  {'id': 'bg_mk_memes_840',
#   'text': "I DON'T KNOW WHY THEY CALL ME KOPEIKIN.",
#   'image': 'bg_mk_memes_840.png'},
#  {'id': 'bg_mk_memes_841',
#   'text': 'Military Commission in the European Union.\n\nRecruitment has begun\nvolunteers for war with Russia...',
#   'image': 'bg_mk_memes_841.png'},
#  {'id': 'bg_mk_memes_845',
#   'text': 'Tonight at sunset everyone pray\nVirgin Mary to stop the war in Ukraine.\nThe Pope will dedicate Ukraine and Russia to\nthe Immaculate Heart of the Virgin!\n\nshare share\nshare.....',
#   'image': 'bg_mk_memes_845.png'},
#  {'id': 'bg_mk_memes_846',
#   'text': '!!! RESIGNATION !!! THE "GREEN" ANTI-ECO MINISTER',
#   'image': 'bg_mk_memes_846.png'},
#  {'id': 'bg_mk_memes_847',
#   'text': "The Minister of Defense in Italy\ntakes office!\nLet's wish her success!\n\nItaly's new defense minister takes office\nposition",
#   'image': 'bg_mk_memes_847.png'},
#  {'id': 'bg_mk_memes_848',
#   'text': 'MICHEL FROM THE RESISTANCE\nRUSSIAN SPIES IN THE MOVIES\n\nRUSSIAN SPIES IN REALITY',
#   'image': 'bg_mk_memes_848.png'},
#  {'id': 'bg_mk_memes_849',
#   'text': 'Neutrality for Bulgaria. We are brothers\nwith the Russian people and the Ukrainian people!',
#   'image': 'bg_mk_memes_849.png'},
#  {'id': 'bg_mk_memes_866',
#   'text': 'THE BULGARIAN PEOPLE\nIS DELIMITED FROM\nSALES POLICIES!\nWE WANT PEACE WITH RUSSIA\nAND BULGARIA - OUT OF\nTHE FASCIST MAFIA!!',
#   'image': 'bg_mk_memes_866.png'},
#  {'id': 'bg_mk_memes_867',
#   'text': 'I paid America\nat one time some billions\nfor some fighters!\n\nWhere are they when we need them?!',
#   'image': 'bg_mk_memes_867.png'},
#  {'id': 'bg_mk_memes_869', 'text': 'NATO', 'image': 'bg_mk_memes_869.png'},
#  {'id': 'bg_mk_memes_870',
#   'text': "As a BBC-funded journalist I have to\nremain consistently politically neutral.\nSo here's a photo of some flowers on a\nsunny day.",
#   'image': 'bg_mk_memes_870.png'},
#  {'id': 'bg_mk_memes_871',
#   'text': 'THESE ARE OUR FRIENDS!',
#   'image': 'bg_mk_memes_871.png'},
#  {'id': 'bg_mk_memes_872',
#   'text': 'Polish moms left strollers at a train\nstation for Ukrainian moms who may need them when they arrive in Poland with kids',
#   'image': 'bg_mk_memes_872.png'},
#  {'id': 'bg_mk_memes_987',
#   'text': 'do you see dawn\nfire Belomor!',
#   'image': 'bg_mk_memes_987.png'},
#  {'id': 'bg_mk_memes_989',
#   'text': 'FRIENDSHIP FOR CENTURIES - FOR CENTURIES!\n\nBULGARIA AND RUSSIA',
#   'image': 'bg_mk_memes_989.png'},
#  {'id': '38',
#   'text': 'Coronavirus\nCOVID-19\nThe vaccine',
#   'image': 'bg_memes_38.png'},
#  {'id': '39',
#   'text': '"If we weren\'t\nspoiled\nRelations with\nRussia would not\nThey share us\nSUCH a bummer.\nGod punishes us\nfor ours\ningratitudeT\nTo her - ours\nLiberator."\n16\nSA\nVanga',
#   'image': 'bg_memes_39.png'},
#  {'id': '40',
#   'text': 'NO EXTRAORDINARY\nPOSITION',
#   'image': 'bg_memes_40.png'},
#  {'id': '42',
#   'text': 'Funny Sad Angry\nFunny Sad Angry\nFunny Sad\nAngry\nSTARECAT.COM\nFunny Sad\nAngry',
#   'image': 'bg_memes_42.png'},
#  {'id': '43',
#   'text': 'BEFORE AND AFTER\nTHE VACCINE',
#   'image': 'bg_memes_43.png'},
#  {'id': '44', 'text': '2D2M\n22 i\n2022\n7.', 'image': 'bg_memes_44.png'},
#  {'id': '45',
#   'text': 'Yes, I support PPPP\nTHE FIVE-ANNIVERSARY FOR\nFOUR YEARS\nANCH\nThe proletariat\nThe five-year period\nFifth International\nNaughty kittens.',
#   'image': 'bg_memes_45.png'},
#  {'id': '47',
#   'text': "Please,\ncalm down!\nWe haven't come\nNOVANEWS\nhere to do\ncircuses!\nL GGG",
#   'image': 'bg_memes_47.png'},
#  {'id': '48',
#   'text': 'I expect kukers in a ministerial council in\nFebruary\nAFP\nMeanwhile, in the US:\nPOL\n8YA6W8\nSaul Loeb/AFP',
#   'image': 'bg_memes_48.png'},
#  {'id': '5', 'text': 'istoricheski_humor\nVETO', 'image': 'bg_memes_5.png'},
#  {'id': '12',
#   'text': 'Slavi: We will send into space\na woman, a man and a Macedonian\nThe parties of the protest:\nMission 121\nimgflip.com',
#   'image': 'bg_memes_12.png'},
#  {'id': '13',
#   'text': 'WHEN THEY SAY THAT THE GOOD\nIT ALWAYS WON, BUT YOU REMEMBER\nWHO WON WORLD WAR II:\nTerezpro Bzarapcko 1lapergo\nimgflip.com',
#   'image': 'bg_memes_13.png'},
#  {'id': '15',
#   'text': "Ol istoricheski_humor\nHOW IT STARTED\nLIVE KABUL\nAL JAZEERA EXCLUSIVE\nHOW IT'S GOING\nimof.com",
#   'image': 'bg_memes_15.png'},
#  {'id': '18',
#   'text': 'USA\nTHE TALIBAN\n2001\nYerrzpTo Bzarapoko LļaperBo\nTHE TALIBAN\n2021\nimgflip.com',
#   'image': 'bg_memes_18.png'},
#  {'id': '19',
#   'text': 'USA\nTHE TALIBAN\n2001\nYerrzpTo Bzarapoko LļaperBo\nTHE TALIBAN\n2021\nimgflip.com',
#   'image': 'bg_memes_19.png'},
#  {'id': '20',
#   'text': 'the communists are\npoisoned boris three\nthe Germans are\npoisoned boris three',
#   'image': 'bg_memes_20.png'},
#  {'id': '21',
#   'text': 'Chaos after the withdrawal of US forces\nand the capture of Soifia by the Mojohideen.\n(Soifia Airport, 2021, colored)\nB AIR FORCE\n1109\nAMERICA FOR\n62 AW\nBULGARIA\n446 AW\nFOUNDATION\nTEPMMNAA2 PT AL 2',
#   'image': 'bg_memes_21.png'},
#  {'id': '22',
#   'text': "What does the vaccine contain?\nPfizer!\nof Bill Gates\nLithium Depresses the will\nand the will to fight.\nBarium Causes cancer\nsterility leukemia\nMercury Kills the immune\nsystem and char. cr. calves\nAluminum Causes\ncancer and vein thrombus\nAntifreeze Destroys\n'brain cells\nDO YOU STILL WANT YES\n20\nm ARE YOU VACCINATED?",
#   'image': 'bg_memes_22.png'},
#  {'id': '23',
#   'text': 'Americano, documents\nchecking\nYou have no right\nUN\nIN\nDONT TREAD ON ME\nGRAY SLOA\nNEMORIA\nHOSPITAL\nGagno, documents for\nchecking\nUN\nCOVID\nLIGMA\nvariant',
#   'image': 'bg_memes_23.png'},
#  {'id': '24',
#   'text': 'Democratic))\nBulgaria\nUNION\nDemocratic\nBulgaria\nI want to live\nin normal\ncountry\nDemocratic\nBulgaria\nUNION\nEEEEEEL\nDemocratic\nBulgaria\nUNITED IE',
#   'image': 'bg_memes_24.png'},
#  {'id': 'bg_mk_memes_934',
#   'text': 'They discovered Russian oil in our waters!',
#   'image': 'bg_mk_memes_934.png'},
#  {'id': 'bg_mk_memes_942',
#   'text': 'Preparation for the destruction of NATO!',
#   'image': 'bg_mk_memes_942.png'},
#  {'id': 'bg_mk_memes_943',
#   'text': '"That one be damned\nthe minute he set foot\na Russian foot in our land."\nZahari Stoyanov\n\n"Russia is not coming to us\nset us free but enslave us\nconquer and devour."\nStefan Stambolov\n\n"A duty sacred to our love\nfatherland forces us to discover\nwhat kind of thing is this Russia and hers\na torturous government."\nGeorgi Rakovski',
#   'image': 'bg_mk_memes_943.png'},
#  {'id': 'bg_mk_memes_944',
#   'text': 'THE BIGGEST TERROR FOR RUSSIA:\nACTOR WHO BECAME PRESIDENT',
#   'image': 'bg_mk_memes_944.png'},
#  {'id': 'bg_mk_memes_945',
#   'text': "How it goes\nwith Russia\ndid you announce\ntheir war\n\nNot yet, but\nI'm working on\nthe question\n\nHe is better\nfrom Zelensky",
#   'image': 'bg_mk_memes_945.png'},
#  {'id': 'bg_mk_memes_946',
#   'text': 'А Bue kЯgЕ bЯХmE, kOGamO na\nkueBckuya mayor his brother beat\nDefenseless Bulgarians?',
#   'image': 'bg_mk_memes_946.png'},
#  {'id': 'bg_mk_memes_947',
#   'text': 'AUDI Q7 HA\nTHE EASTERN BLOCK',
#   'image': 'bg_mk_memes_947.png'},
#  {'id': 'bg_mk_memes_948',
#   'text': 'Kat RuZia has no Tue...\nShut up!',
#   'image': 'bg_mk_memes_948.png'},
#  {'id': 'bg_mk_memes_950',
#   'text': 'Hello Will Smith? Did you hear what he said?\nPutin for your wife?',
#   'image': 'bg_mk_memes_950.png'},
#  {'id': 'bg_mk_memes_953',
#   'text': "A LOT of gas\nA village in Putin's Russia\n\nwithout gas\nA village in the gendered EU/ Germany",
#   'image': 'bg_mk_memes_953.png'},
#  {'id': '64',
#   'text': 'Macedonia trying to\ncontinued negotiations for\nentry into the EU, 2021 (colored)\nRo\nimaflip.com',
#   'image': 'bg_memes_64.png'},
#  {'id': '65',
#   'text': 'i\nbgnes.bg\nThe President of the Macedonian Academy:\nRSM was under 100 years of Bulgarian slavery',
#   'image': 'bg_memes_65.png'},
#  {'id': '66',
#   'text': 'The Macedonians, when\nstart talking about\nyour "great" story\n@meme_partiq',
#   'image': 'bg_memes_66.png'},
#  {'id': '67',
#   'text': "Me: I'm not going to talk about politics\nMe too, after the third brandy:\n@meme рartiq",
#   'image': 'bg_memes_67.png'},
#  {'id': '68',
#   'text': '@meme_partiq\nCircus\nA much bigger Circus',
#   'image': 'bg_memes_68.png'},
#  {'id': '69',
#   'text': "With this joke, Albanian Prime Minister Edi Rama\nturned to his Macedonian counterpart\nZoran Zaev at the economic forum in\nSkopje.\nDIARY bg\ndnevnik.bg\nQuote of the day: I hope they don't ask to\nname Western Bulgaria",
#   'image': 'bg_memes_69.png'},
#  {'id': '75',
#   'text': "She never was!\nWait, Earth doesn't\nis Macedonian?",
#   'image': 'bg_memes_75.png'},
#  {'id': 'bg_mk_memes_952',
#   'text': 'Neutrality for\nBulgaria. We are brothers\nand with the Russian people and\nUkrainian people!',
#   'image': 'bg_mk_memes_952.png'},
#  {'id': 'bg_mk_memes_954',
#   'text': 'What is she\nthe situation in\nSofia,\nBulgaria\nare they at war with\nus\n\nJudging by the way\nwho buy oil.\nPetkov must be crazy\nto give them weapons\n\nAnd if they\ngave\n\nHalf will\nshoot at politicians\nthe other half by\nthe US Embassy',
#   'image': 'bg_mk_memes_954.png'},
#  {'id': 'bg_mk_memes_956',
#   'text': 'We will abandon the Mendeleian table,\nbecause it was invented by a Russian - Dmitry\nIvanovich Mendeleev!',
#   'image': 'bg_mk_memes_956.png'},
#  {'id': 'bg_mk_memes_958',
#   'text': 'If Putin attacks a country from\nNato, I will immediately throw away\nthis NATO country',
#   'image': 'bg_mk_memes_958.png'},
#  {'id': 'bg_mk_memes_960',
#   'text': 'I AM\nAGAINST NATO AND\nTHE DISPOSAL OF\nTROOPS IN BULGARIA\nREACE',
#   'image': 'bg_mk_memes_960.png'},
#  {'id': 'bg_mk_memes_961',
#   'text': 'Biden shared his opinion on\nRussian hypersonic missile\n.Dagger ": .It\'s like any other\nrocket. She is almost unstoppable.\n"She has the same warhead\nlike any other rocket. There is no\nbig difference except it\'s almost\nimpossible to stop"',
#   'image': 'bg_mk_memes_961.png'},
#  {'id': 'bg_mk_memes_962',
#   'text': 'There are refugees and refugees!\nAre some people human and others not?\n\nUkraine\nMuslims',
#   'image': 'bg_mk_memes_962.png'},
#  {'id': 'bg_mk_memes_963',
#   'text': "wait where did you run\nI didn't give you a brain\n\nI CAN'T...I HAVE TO\nCOMMENTING\nEVENTS and the war\nin UKRAINE",
#   'image': 'bg_mk_memes_963.png'},
#  {'id': 'bg_mk_memes_964',
#   'text': "I'll be at the hen's house!",
#   'image': 'bg_mk_memes_964.png'},
#  {'id': 'bg_mk_memes_965',
#   'text': 'LET THE BULGARIAN PEOPLE\nNEVER FORGET,\nTHAT HE OWES HIS FREEDOM\nTO HIS RUSSIAN BROTHERS,\nIS YOUR LIFE FOR HER!',
#   'image': 'bg_mk_memes_965.png'},
#  {'id': 'bg_mk_memes_966',
#   'text': 'BULGARIANS!\nOn 03.03, celebrating Liberation\nof Bulgaria from Turkish slavery,\nremember well who set you free!',
#   'image': 'bg_mk_memes_966.png'},
#  {'id': 'bg_mk_memes_375',
#   'text': 'M3: You will enter everywhere with a green certificate\n\nBest l can do is kpash the system',
#   'image': 'bg_mk_memes_375.png'},
#  {'id': 'bg_memes_468',
#   'text': 'Open your cheeks...',
#   'image': 'bg_memes_468.png'},
#  {'id': 'bg_memes_498', 'text': 'A PANDEMIC', 'image': 'bg_memes_498.png'},
#  {'id': 'bg_memes_500',
#   'text': 'Dinko from Yambol: I will bring out the tank if Russia threatens us',
#   'image': 'bg_memes_500.png'},
#  {'id': 'bg_memes_507',
#   'text': 'BULGARIAN RAM BASIL\n\nwho is he?',
#   'image': 'bg_memes_507.png'},
#  {'id': 'bg_memes_508',
#   'text': 'carpet\ncarpet\ncarpet\n\nmedia\n\nCoward!\nUkraine\nClick\n\nUkraine\nUkraine\nUkraine\nUkraine',
#   'image': 'bg_memes_508.png'},
#  {'id': 'bg_memes_447',
#   'text': 'Putin complicates geography exams',
#   'image': 'bg_memes_447.png'},
#  {'id': 'bg_mk_memes_826',
#   'text': 'A Russian tank saw Bayraktar, se\npretending to be dead...',
#   'image': 'bg_mk_memes_826.png'},
#  {'id': 'bg_mk_memes_827',
#   'text': 'KOPEIKIN AT THE CURRENT RUBLE RATE',
#   'image': 'bg_mk_memes_827.png'},
#  {'id': 'bg_mk_memes_828',
#   'text': 'Both are from VguzRazdani',
#   'image': 'bg_mk_memes_828.png'},
#  {'id': 'bg_mk_memes_829',
#   'text': "wait where did you run\nI didn't give you a brain\n\nI CAN'T...I HAVE TO\nCOMMENTING\nTHE EVENTS and WAR\nIN UKRAINE",
#   'image': 'bg_mk_memes_829.png'},
#  {'id': 'bg_mk_memes_830',
#   'text': 'А Bue kЯgЕ bЯХmE, kOGamO na\nkueBckuya mayor his brother beat\nDefenseless Bulgarians?',
#   'image': 'bg_mk_memes_830.png'},
#  {'id': 'bg_mk_memes_831',
#   'text': 'Ukrainian girl teaches uncle Ahmet,\nto speak Ukrainian.\n\nHow are you?\nYa tebia, he wants to cool down.',
#   'image': 'bg_mk_memes_831.png'},
#  {'id': 'bg_mk_memes_832',
#   'text': 'This fountain from 1762 in the center\nof Gabrovo is 14 years old\n"bigger" than the US',
#   'image': 'bg_mk_memes_832.png'},
#  {'id': 'bg_mk_memes_833',
#   'text': 'I AM THE EMERALD\nDRAGON! REVIVAL ONLY\nAND HOLY MASTER\nA REVIVAL!\n\nTHE SAVIOR OF BULGARIA!\n\nCat, take your pills',
#   'image': 'bg_mk_memes_833.png'},
#  {'id': 'bg_mk_memes_834',
#   'text': 'WHICH ARREST IS\nHUMILIATING?\n\n12 seconds\nbeing visible\n\n12 HOURS\non display with handcuffs behind\nback, no water, toilet,\nin front of the media and\nsociety',
#   'image': 'bg_mk_memes_834.png'},
#  {'id': '76',
#   'text': 'Dad Dad || yes\nI am\nMacedonia\nthe\nYou will burn at the stake\nyou such an atheist',
#   'image': 'bg_memes_76.png'},
#  {'id': '8',
#   'text': 'MACEDONIA and\nBULGARIA\nMACEDONIA and\n- BULGARIA\nTHEY CAN UNDERSTAND THEY CAN UNDERSTAND\nAND TO BE IN HARMONY\nAND TO BE IN HARMONY\nMACEDONIA AND BULGARIA\nTHEY CAN UNDERSTAND\nAND TO BE IN HARMONY\nMACEDONIA\nBULGARIA!!!',
#   'image': 'bg_memes_8.png'},
#  {'id': '9',
#   'text': 'THE AMERICAN DREAM\nglasspar\nDoughboy\nCHATIES\nChiemen\nRayai Chaf\nTHE BULGARIAN DREAM\nHA\nKruševac\nRazgrad\nDobrich\nFerdinand\nPleven\nNoisy\nNiche\nVarna\nN. market\nPirot\nVratsa\nTrnovo\nK. Mitrovitsa\nGabrovo\nSOFIA\nSliven\nPristina\nA pillowcase\nBlack Sea\n. Vranya\nStara Zagora\nYambol\nBurgas\nKyustendil\nDespicable,\nPazardzhik\nPlovdiv\nCuckoo\n.Kumanovo\nTetovo\nSkopje\nUpper Jumaya\nHaskovo\nVeles\nA pinch\nEdirne\nLozengrad\nKurdzhali\nNeurocop\nSmolyan\n.Debar\nStrumica\nLilleburgas\nA bat\nStrictly\nOhrid\nBitola\nDrama\nXanthi gumurgina\nIstanbul\nRodosto\nCuckoo\nKavala\nDedeajach\nLerin\nWatery\nMarmara Sea\nKorcha\nThessaloniki\nsharp\nSamothraces\nGalileo\nLeather ones\nCatherine\nWhite Sea\nGrilled\n.Canakkale',
#   'image': 'bg_memes_9.png'},
#  {'id': 'bg_mk_memes_990',
#   'text': 'Starting today, we announce the code "Red" for the whole country.',
#   'image': 'bg_mk_memes_990.png'},
#  {'id': 'bg_mk_memes_992',
#   'text': 'i can smell tinsel',
#   'image': 'bg_mk_memes_992.png'},
#  {'id': 'bg_mk_memes_993',
#   'text': 'AFTER BLACK FRIDAY, THE WHITE SNOW CAME',
#   'image': 'bg_mk_memes_993.png'},
#  {'id': 'bg_mk_memes_995',
#   'text': "I succeeded! 3 more kilos and I'm at zero.",
#   'image': 'bg_mk_memes_995.png'},
#  {'id': 'bg_mk_memes_997',
#   'text': "When you find someone perpetually dissatisfied like you.\nIt's not pretty.\nI don't like it either.",
#   'image': 'bg_mk_memes_997.png'},
#  {'id': 'bg_mk_memes_998',
#   'text': 'Sometimes we just have to leave problems behind.',
#   'image': 'bg_mk_memes_998.png'},
#  {'id': 'bg_mk_memes_999',
#   'text': 'Road infrastructure wishes you "Love each other"',
#   'image': 'bg_mk_memes_999.png'},
#  {'id': 'bg_mk_memes_1005',
#   'text': 'TETRIS FOR 40+ YEARS OLD',
#   'image': 'bg_mk_memes_1005.png'},
#  {'id': 'bg_mk_memes_1010',
#   'text': 'But mom, school opens in 6 days?!\nNo problem. Go slow!',
#   'image': 'bg_mk_memes_1010.png'},
#  {'id': 'bg_mk_memes_1024',
#   'text': 'half a bottle\nAvera, who did not give money because he is sick and will not drink\nI',
#   'image': 'bg_mk_memes_1024.png'}]

# %%
"""
for utterance in trial_data:
  d = trained_nlp(utterance["text"]).cats
  label = max(d, key =d.get)
  utterance["label"] = label
"""
# Out:
# '\nfor utterance in trial_data:\n  d = trained_nlp(utterance["text"]).cats\n  label = max(d, key =d.get)\n  utterance["label"] = label\n'

# %%
#CANGED
for utterance in trial_data:
  try:
    texty = utterance["text"].replace("\\n", " ").lower()    #removing new-line-characters(\\n) and lowering the text
  except:
    texty = utterance["text"].lower()
  d = trained_nlp(texty).cats
  label = max(d, key =d.get)
  utterance["label"] = label

# %%
trial_data
# Out:
# [{'id': '1',
#   'text': 'When you wake up after being healed\nnight you got vaccinated against\ncoronavirus/I',
#   'image': 'bg_memes_1.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_984',
#   'text': "What's in Kostya Kopeikin: ACE\n\nWhat's in Kiril Petkov:",
#   'image': 'bg_mk_memes_984.png',
#   'label': 'propagandistic'},
#  {'id': '4',
#   'text': 'HOW DO YOU FEEL?\nSUDDENLY I FELT\nAN UNEXPLAINABLE NEED\nTO REGISTER WINDOWS-A',
#   'image': 'bg_memes_4.png',
#   'label': 'non_propagandistic'},
#  {'id': '41',
#   'text': 'I NEVER BELIEVED THAT\nTHE BEGINNING OF THE JOKES WILL TURN OUT TO BE TRUE:\nBYE GANYO BULGARINA\nAND BYE GANYO THE AMERICAN...\nimgflip.com',
#   'image': 'bg_memes_41.png',
#   'label': 'non_propagandistic'},
#  {'id': '49',
#   'text': 'i\n2 hours after vaccination\nPIK',
#   'image': 'bg_memes_49.png',
#   'label': 'non_propagandistic'},
#  {'id': '50',
#   'text': 'BEFORE THE VACCINE\nTHE POST-VACCINE\nimgflip.com',
#   'image': 'bg_memes_50.png',
#   'label': 'non_propagandistic'},
#  {'id': '52',
#   'text': 'EC: No increase in the number of\nrefugees from Afghanistan\n07.10.2021 | 00:41 min | Download\n@meme_рartiq\nDinko from\nYambol:',
#   'image': 'bg_memes_52.png',
#   'label': 'non_propagandistic'},
#  {'id': '53',
#   'text': '7 election victories\nin one photo\n@meme_partiq',
#   'image': 'bg_memes_53.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_840',
#   'text': "I DON'T KNOW WHY THEY CALL ME KOPEIKIN.",
#   'image': 'bg_mk_memes_840.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_841',
#   'text': 'Military Commission in the European Union.\n\nRecruitment has begun\nvolunteers for war with Russia...',
#   'image': 'bg_mk_memes_841.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_845',
#   'text': 'Tonight at sunset everyone pray\nVirgin Mary to stop the war in Ukraine.\nThe Pope will dedicate Ukraine and Russia to\nthe Immaculate Heart of the Virgin!\n\nshare share\nshare.....',
#   'image': 'bg_mk_memes_845.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_846',
#   'text': '!!! RESIGNATION !!! THE "GREEN" ANTI-ECO MINISTER',
#   'image': 'bg_mk_memes_846.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_847',
#   'text': "The Minister of Defense in Italy\ntakes office!\nLet's wish her success!\n\nItaly's new defense minister takes office\nposition",
#   'image': 'bg_mk_memes_847.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_848',
#   'text': 'MICHEL FROM THE RESISTANCE\nRUSSIAN SPIES IN THE MOVIES\n\nRUSSIAN SPIES IN REALITY',
#   'image': 'bg_mk_memes_848.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_849',
#   'text': 'Neutrality for Bulgaria. We are brothers\nwith the Russian people and the Ukrainian people!',
#   'image': 'bg_mk_memes_849.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_866',
#   'text': 'THE BULGARIAN PEOPLE\nIS DELIMITED FROM\nSALES POLICIES!\nWE WANT PEACE WITH RUSSIA\nAND BULGARIA - OUT OF\nTHE FASCIST MAFIA!!',
#   'image': 'bg_mk_memes_866.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_867',
#   'text': 'I paid America\nat one time some billions\nfor some fighters!\n\nWhere are they when we need them?!',
#   'image': 'bg_mk_memes_867.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_869',
#   'text': 'NATO',
#   'image': 'bg_mk_memes_869.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_870',
#   'text': "As a BBC-funded journalist I have to\nremain consistently politically neutral.\nSo here's a photo of some flowers on a\nsunny day.",
#   'image': 'bg_mk_memes_870.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_871',
#   'text': 'THESE ARE OUR FRIENDS!',
#   'image': 'bg_mk_memes_871.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_872',
#   'text': 'Polish moms left strollers at a train\nstation for Ukrainian moms who may need them when they arrive in Poland with kids',
#   'image': 'bg_mk_memes_872.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_987',
#   'text': 'do you see dawn\nfire Belomor!',
#   'image': 'bg_mk_memes_987.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_989',
#   'text': 'FRIENDSHIP FOR CENTURIES - FOR CENTURIES!\n\nBULGARIA AND RUSSIA',
#   'image': 'bg_mk_memes_989.png',
#   'label': 'propagandistic'},
#  {'id': '38',
#   'text': 'Coronavirus\nCOVID-19\nThe vaccine',
#   'image': 'bg_memes_38.png',
#   'label': 'non_propagandistic'},
#  {'id': '39',
#   'text': '"If we weren\'t\nspoiled\nRelations with\nRussia would not\nThey share us\nSUCH a bummer.\nGod punishes us\nfor ours\ningratitudeT\nTo her - ours\nLiberator."\n16\nSA\nVanga',
#   'image': 'bg_memes_39.png',
#   'label': 'non_propagandistic'},
#  {'id': '40',
#   'text': 'NO EXTRAORDINARY\nPOSITION',
#   'image': 'bg_memes_40.png',
#   'label': 'non_propagandistic'},
#  {'id': '42',
#   'text': 'Funny Sad Angry\nFunny Sad Angry\nFunny Sad\nAngry\nSTARECAT.COM\nFunny Sad\nAngry',
#   'image': 'bg_memes_42.png',
#   'label': 'non_propagandistic'},
#  {'id': '43',
#   'text': 'BEFORE AND AFTER\nTHE VACCINE',
#   'image': 'bg_memes_43.png',
#   'label': 'non_propagandistic'},
#  {'id': '44',
#   'text': '2D2M\n22 i\n2022\n7.',
#   'image': 'bg_memes_44.png',
#   'label': 'non_propagandistic'},
#  {'id': '45',
#   'text': 'Yes, I support PPPP\nTHE FIVE-ANNIVERSARY FOR\nFOUR YEARS\nANCH\nThe proletariat\nThe five-year period\nFifth International\nNaughty kittens.',
#   'image': 'bg_memes_45.png',
#   'label': 'non_propagandistic'},
#  {'id': '47',
#   'text': "Please,\ncalm down!\nWe haven't come\nNOVANEWS\nhere to do\ncircuses!\nL GGG",
#   'image': 'bg_memes_47.png',
#   'label': 'non_propagandistic'},
#  {'id': '48',
#   'text': 'I expect kukers in a ministerial council in\nFebruary\nAFP\nMeanwhile, in the US:\nPOL\n8YA6W8\nSaul Loeb/AFP',
#   'image': 'bg_memes_48.png',
#   'label': 'non_propagandistic'},
#  {'id': '5',
#   'text': 'istoricheski_humor\nVETO',
#   'image': 'bg_memes_5.png',
#   'label': 'non_propagandistic'},
#  {'id': '12',
#   'text': 'Slavi: We will send into space\na woman, a man and a Macedonian\nThe parties of the protest:\nMission 121\nimgflip.com',
#   'image': 'bg_memes_12.png',
#   'label': 'non_propagandistic'},
#  {'id': '13',
#   'text': 'WHEN THEY SAY THAT THE GOOD\nIT ALWAYS WON, BUT YOU REMEMBER\nWHO WON WORLD WAR II:\nTerezpro Bzarapcko 1lapergo\nimgflip.com',
#   'image': 'bg_memes_13.png',
#   'label': 'non_propagandistic'},
#  {'id': '15',
#   'text': "Ol istoricheski_humor\nHOW IT STARTED\nLIVE KABUL\nAL JAZEERA EXCLUSIVE\nHOW IT'S GOING\nimof.com",
#   'image': 'bg_memes_15.png',
#   'label': 'non_propagandistic'},
#  {'id': '18',
#   'text': 'USA\nTHE TALIBAN\n2001\nYerrzpTo Bzarapoko LļaperBo\nTHE TALIBAN\n2021\nimgflip.com',
#   'image': 'bg_memes_18.png',
#   'label': 'non_propagandistic'},
#  {'id': '19',
#   'text': 'USA\nTHE TALIBAN\n2001\nYerrzpTo Bzarapoko LļaperBo\nTHE TALIBAN\n2021\nimgflip.com',
#   'image': 'bg_memes_19.png',
#   'label': 'non_propagandistic'},
#  {'id': '20',
#   'text': 'the communists are\npoisoned boris three\nthe Germans are\npoisoned boris three',
#   'image': 'bg_memes_20.png',
#   'label': 'non_propagandistic'},
#  {'id': '21',
#   'text': 'Chaos after the withdrawal of US forces\nand the capture of Soifia by the Mojohideen.\n(Soifia Airport, 2021, colored)\nB AIR FORCE\n1109\nAMERICA FOR\n62 AW\nBULGARIA\n446 AW\nFOUNDATION\nTEPMMNAA2 PT AL 2',
#   'image': 'bg_memes_21.png',
#   'label': 'non_propagandistic'},
#  {'id': '22',
#   'text': "What does the vaccine contain?\nPfizer!\nof Bill Gates\nLithium Depresses the will\nand the will to fight.\nBarium Causes cancer\nsterility leukemia\nMercury Kills the immune\nsystem and char. cr. calves\nAluminum Causes\ncancer and vein thrombus\nAntifreeze Destroys\n'brain cells\nDO YOU STILL WANT YES\n20\nm ARE YOU VACCINATED?",
#   'image': 'bg_memes_22.png',
#   'label': 'non_propagandistic'},
#  {'id': '23',
#   'text': 'Americano, documents\nchecking\nYou have no right\nUN\nIN\nDONT TREAD ON ME\nGRAY SLOA\nNEMORIA\nHOSPITAL\nGagno, documents for\nchecking\nUN\nCOVID\nLIGMA\nvariant',
#   'image': 'bg_memes_23.png',
#   'label': 'non_propagandistic'},
#  {'id': '24',
#   'text': 'Democratic))\nBulgaria\nUNION\nDemocratic\nBulgaria\nI want to live\nin normal\ncountry\nDemocratic\nBulgaria\nUNION\nEEEEEEL\nDemocratic\nBulgaria\nUNITED IE',
#   'image': 'bg_memes_24.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_934',
#   'text': 'They discovered Russian oil in our waters!',
#   'image': 'bg_mk_memes_934.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_942',
#   'text': 'Preparation for the destruction of NATO!',
#   'image': 'bg_mk_memes_942.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_943',
#   'text': '"That one be damned\nthe minute he set foot\na Russian foot in our land."\nZahari Stoyanov\n\n"Russia is not coming to us\nset us free but enslave us\nconquer and devour."\nStefan Stambolov\n\n"A duty sacred to our love\nfatherland forces us to discover\nwhat kind of thing is this Russia and hers\na torturous government."\nGeorgi Rakovski',
#   'image': 'bg_mk_memes_943.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_944',
#   'text': 'THE BIGGEST TERROR FOR RUSSIA:\nACTOR WHO BECAME PRESIDENT',
#   'image': 'bg_mk_memes_944.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_945',
#   'text': "How it goes\nwith Russia\ndid you announce\ntheir war\n\nNot yet, but\nI'm working on\nthe question\n\nHe is better\nfrom Zelensky",
#   'image': 'bg_mk_memes_945.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_946',
#   'text': 'А Bue kЯgЕ bЯХmE, kOGamO na\nkueBckuya mayor his brother beat\nDefenseless Bulgarians?',
#   'image': 'bg_mk_memes_946.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_947',
#   'text': 'AUDI Q7 HA\nTHE EASTERN BLOCK',
#   'image': 'bg_mk_memes_947.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_948',
#   'text': 'Kat RuZia has no Tue...\nShut up!',
#   'image': 'bg_mk_memes_948.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_950',
#   'text': 'Hello Will Smith? Did you hear what he said?\nPutin for your wife?',
#   'image': 'bg_mk_memes_950.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_953',
#   'text': "A LOT of gas\nA village in Putin's Russia\n\nwithout gas\nA village in the gendered EU/ Germany",
#   'image': 'bg_mk_memes_953.png',
#   'label': 'propagandistic'},
#  {'id': '64',
#   'text': 'Macedonia trying to\ncontinued negotiations for\nentry into the EU, 2021 (colored)\nRo\nimaflip.com',
#   'image': 'bg_memes_64.png',
#   'label': 'non_propagandistic'},
#  {'id': '65',
#   'text': 'i\nbgnes.bg\nThe President of the Macedonian Academy:\nRSM was under 100 years of Bulgarian slavery',
#   'image': 'bg_memes_65.png',
#   'label': 'non_propagandistic'},
#  {'id': '66',
#   'text': 'The Macedonians, when\nstart talking about\nyour "great" story\n@meme_partiq',
#   'image': 'bg_memes_66.png',
#   'label': 'non_propagandistic'},
#  {'id': '67',
#   'text': "Me: I'm not going to talk about politics\nMe too, after the third brandy:\n@meme рartiq",
#   'image': 'bg_memes_67.png',
#   'label': 'non_propagandistic'},
#  {'id': '68',
#   'text': '@meme_partiq\nCircus\nA much bigger Circus',
#   'image': 'bg_memes_68.png',
#   'label': 'non_propagandistic'},
#  {'id': '69',
#   'text': "With this joke, Albanian Prime Minister Edi Rama\nturned to his Macedonian counterpart\nZoran Zaev at the economic forum in\nSkopje.\nDIARY bg\ndnevnik.bg\nQuote of the day: I hope they don't ask to\nname Western Bulgaria",
#   'image': 'bg_memes_69.png',
#   'label': 'non_propagandistic'},
#  {'id': '75',
#   'text': "She never was!\nWait, Earth doesn't\nis Macedonian?",
#   'image': 'bg_memes_75.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_952',
#   'text': 'Neutrality for\nBulgaria. We are brothers\nand with the Russian people and\nUkrainian people!',
#   'image': 'bg_mk_memes_952.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_954',
#   'text': 'What is she\nthe situation in\nSofia,\nBulgaria\nare they at war with\nus\n\nJudging by the way\nwho buy oil.\nPetkov must be crazy\nto give them weapons\n\nAnd if they\ngave\n\nHalf will\nshoot at politicians\nthe other half by\nthe US Embassy',
#   'image': 'bg_mk_memes_954.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_956',
#   'text': 'We will abandon the Mendeleian table,\nbecause it was invented by a Russian - Dmitry\nIvanovich Mendeleev!',
#   'image': 'bg_mk_memes_956.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_958',
#   'text': 'If Putin attacks a country from\nNato, I will immediately throw away\nthis NATO country',
#   'image': 'bg_mk_memes_958.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_960',
#   'text': 'I AM\nAGAINST NATO AND\nTHE DISPOSAL OF\nTROOPS IN BULGARIA\nREACE',
#   'image': 'bg_mk_memes_960.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_961',
#   'text': 'Biden shared his opinion on\nRussian hypersonic missile\n.Dagger ": .It\'s like any other\nrocket. She is almost unstoppable.\n"She has the same warhead\nlike any other rocket. There is no\nbig difference except it\'s almost\nimpossible to stop"',
#   'image': 'bg_mk_memes_961.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_962',
#   'text': 'There are refugees and refugees!\nAre some people human and others not?\n\nUkraine\nMuslims',
#   'image': 'bg_mk_memes_962.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_963',
#   'text': "wait where did you run\nI didn't give you a brain\n\nI CAN'T...I HAVE TO\nCOMMENTING\nEVENTS and the war\nin UKRAINE",
#   'image': 'bg_mk_memes_963.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_964',
#   'text': "I'll be at the hen's house!",
#   'image': 'bg_mk_memes_964.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_965',
#   'text': 'LET THE BULGARIAN PEOPLE\nNEVER FORGET,\nTHAT HE OWES HIS FREEDOM\nTO HIS RUSSIAN BROTHERS,\nIS YOUR LIFE FOR HER!',
#   'image': 'bg_mk_memes_965.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_966',
#   'text': 'BULGARIANS!\nOn 03.03, celebrating Liberation\nof Bulgaria from Turkish slavery,\nremember well who set you free!',
#   'image': 'bg_mk_memes_966.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_375',
#   'text': 'M3: You will enter everywhere with a green certificate\n\nBest l can do is kpash the system',
#   'image': 'bg_mk_memes_375.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_memes_468',
#   'text': 'Open your cheeks...',
#   'image': 'bg_memes_468.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_memes_498',
#   'text': 'A PANDEMIC',
#   'image': 'bg_memes_498.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_memes_500',
#   'text': 'Dinko from Yambol: I will bring out the tank if Russia threatens us',
#   'image': 'bg_memes_500.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_memes_507',
#   'text': 'BULGARIAN RAM BASIL\n\nwho is he?',
#   'image': 'bg_memes_507.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_memes_508',
#   'text': 'carpet\ncarpet\ncarpet\n\nmedia\n\nCoward!\nUkraine\nClick\n\nUkraine\nUkraine\nUkraine\nUkraine',
#   'image': 'bg_memes_508.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_memes_447',
#   'text': 'Putin complicates geography exams',
#   'image': 'bg_memes_447.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_826',
#   'text': 'A Russian tank saw Bayraktar, se\npretending to be dead...',
#   'image': 'bg_mk_memes_826.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_827',
#   'text': 'KOPEIKIN AT THE CURRENT RUBLE RATE',
#   'image': 'bg_mk_memes_827.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_828',
#   'text': 'Both are from VguzRazdani',
#   'image': 'bg_mk_memes_828.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_829',
#   'text': "wait where did you run\nI didn't give you a brain\n\nI CAN'T...I HAVE TO\nCOMMENTING\nTHE EVENTS and WAR\nIN UKRAINE",
#   'image': 'bg_mk_memes_829.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_830',
#   'text': 'А Bue kЯgЕ bЯХmE, kOGamO na\nkueBckuya mayor his brother beat\nDefenseless Bulgarians?',
#   'image': 'bg_mk_memes_830.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_831',
#   'text': 'Ukrainian girl teaches uncle Ahmet,\nto speak Ukrainian.\n\nHow are you?\nYa tebia, he wants to cool down.',
#   'image': 'bg_mk_memes_831.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_832',
#   'text': 'This fountain from 1762 in the center\nof Gabrovo is 14 years old\n"bigger" than the US',
#   'image': 'bg_mk_memes_832.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_833',
#   'text': 'I AM THE EMERALD\nDRAGON! REVIVAL ONLY\nAND HOLY MASTER\nA REVIVAL!\n\nTHE SAVIOR OF BULGARIA!\n\nCat, take your pills',
#   'image': 'bg_mk_memes_833.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_834',
#   'text': 'WHICH ARREST IS\nHUMILIATING?\n\n12 seconds\nbeing visible\n\n12 HOURS\non display with handcuffs behind\nback, no water, toilet,\nin front of the media and\nsociety',
#   'image': 'bg_mk_memes_834.png',
#   'label': 'non_propagandistic'},
#  {'id': '76',
#   'text': 'Dad Dad || yes\nI am\nMacedonia\nthe\nYou will burn at the stake\nyou such an atheist',
#   'image': 'bg_memes_76.png',
#   'label': 'non_propagandistic'},
#  {'id': '8',
#   'text': 'MACEDONIA and\nBULGARIA\nMACEDONIA and\n- BULGARIA\nTHEY CAN UNDERSTAND THEY CAN UNDERSTAND\nAND TO BE IN HARMONY\nAND TO BE IN HARMONY\nMACEDONIA AND BULGARIA\nTHEY CAN UNDERSTAND\nAND TO BE IN HARMONY\nMACEDONIA\nBULGARIA!!!',
#   'image': 'bg_memes_8.png',
#   'label': 'non_propagandistic'},
#  {'id': '9',
#   'text': 'THE AMERICAN DREAM\nglasspar\nDoughboy\nCHATIES\nChiemen\nRayai Chaf\nTHE BULGARIAN DREAM\nHA\nKruševac\nRazgrad\nDobrich\nFerdinand\nPleven\nNoisy\nNiche\nVarna\nN. market\nPirot\nVratsa\nTrnovo\nK. Mitrovitsa\nGabrovo\nSOFIA\nSliven\nPristina\nA pillowcase\nBlack Sea\n. Vranya\nStara Zagora\nYambol\nBurgas\nKyustendil\nDespicable,\nPazardzhik\nPlovdiv\nCuckoo\n.Kumanovo\nTetovo\nSkopje\nUpper Jumaya\nHaskovo\nVeles\nA pinch\nEdirne\nLozengrad\nKurdzhali\nNeurocop\nSmolyan\n.Debar\nStrumica\nLilleburgas\nA bat\nStrictly\nOhrid\nBitola\nDrama\nXanthi gumurgina\nIstanbul\nRodosto\nCuckoo\nKavala\nDedeajach\nLerin\nWatery\nMarmara Sea\nKorcha\nThessaloniki\nsharp\nSamothraces\nGalileo\nLeather ones\nCatherine\nWhite Sea\nGrilled\n.Canakkale',
#   'image': 'bg_memes_9.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_990',
#   'text': 'Starting today, we announce the code "Red" for the whole country.',
#   'image': 'bg_mk_memes_990.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_992',
#   'text': 'i can smell tinsel',
#   'image': 'bg_mk_memes_992.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_993',
#   'text': 'AFTER BLACK FRIDAY, THE WHITE SNOW CAME',
#   'image': 'bg_mk_memes_993.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_995',
#   'text': "I succeeded! 3 more kilos and I'm at zero.",
#   'image': 'bg_mk_memes_995.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_997',
#   'text': "When you find someone perpetually dissatisfied like you.\nIt's not pretty.\nI don't like it either.",
#   'image': 'bg_mk_memes_997.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_998',
#   'text': 'Sometimes we just have to leave problems behind.',
#   'image': 'bg_mk_memes_998.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_999',
#   'text': 'Road infrastructure wishes you "Love each other"',
#   'image': 'bg_mk_memes_999.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_1005',
#   'text': 'TETRIS FOR 40+ YEARS OLD',
#   'image': 'bg_mk_memes_1005.png',
#   'label': 'propagandistic'},
#  {'id': 'bg_mk_memes_1010',
#   'text': 'But mom, school opens in 6 days?!\nNo problem. Go slow!',
#   'image': 'bg_mk_memes_1010.png',
#   'label': 'non_propagandistic'},
#  {'id': 'bg_mk_memes_1024',
#   'text': 'half a bottle\nAvera, who did not give money because he is sick and will not drink\nI',
#   'image': 'bg_mk_memes_1024.png',
#   'label': 'non_propagandistic'}]

# %% [markdown]
# #Submition Format
# "Subtask2b.txt", which means that the "Subtask2b.json" file should be renamed

# %%
dir = "Subtask2b.json"
data = trial_data

# %%
with open(dir, mode="wt", encoding = "utf-8") as f:
  json.dump(data,f,ensure_ascii=False, indent=4)
