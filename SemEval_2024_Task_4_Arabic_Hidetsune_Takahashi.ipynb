# %% [markdown]
# <a href="https://colab.research.google.com/github/Hidetsune/SemEval2024_Task4/blob/main/SemEval_2024_Task_4_Arabic_Hidetsune_Takahashi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import and Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import json

# %%
import re

# %%
training_validation_data = pd.read_csv("/content/drive/MyDrive/SemEval Task4/task4_data_concat_extended5.csv") # task5_data_concat_extended4.csv   (CHANGE HERE)
training_validation_data
# Out:
#                                                     text  \
# 0       we're here to help! send us a dm with your em...
# 1      then   now  raise your hand if jill should res...
# 2       hello, this does not sound good.  can you dm ...
# 3       sorry for the delay, katie! we'd like to inve...
# 4      you should have to pass a drug test to receive...
# ...                                                  ...
# 20769  writing for facerook tio apoloigai td mlrldott...
# 20770   hey matthew, flight 783 is showing a late arr...
# 20771   if the permissions cannot be disabled, they m...
# 20772   isn't prime two day shipping supposed to be g...
# 20773  chosen by god backed by our military. surround...
#
#       propagandistic/non_propagandistic
# 0                    non_propagandistic
# 1                        propagandistic
# 2                    non_propagandistic
# 3                    non_propagandistic
# 4                        propagandistic
# ...                                 ...
# 20769                    propagandistic
# 20770                non_propagandistic
# 20771                non_propagandistic
# 20772                non_propagandistic
# 20773                    propagandistic
#
# [20774 rows x 2 columns]

# %%
# !pip install "spacy >= 3.0.6"
# !pip install "comet_ml>=3.31.19"
# !pip install datasets
# Out:
# Requirement already satisfied: spacy>=3.0.6 in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (1.10.14)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.0.6) (3.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy>=3.0.6) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.6) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.6) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.0.6) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.0.6) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy>=3.0.6) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=3.0.6) (2.1.4)
# Collecting comet_ml>=3.31.19
#   Downloading comet_ml-3.37.0-py3-none-any.whl (599 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.4/599.4 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (4.19.2)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml>=3.31.19)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 33.9 MB/s eta 0:00:00
# Collecting requests-toolbelt>=0.8.0 (from comet_ml>=3.31.19)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (2.31.0)
# Collecting semantic-version>=2.8.0 (from comet_ml>=3.31.19)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting sentry-sdk>=1.1.0 (from comet_ml>=3.31.19)
#   Downloading sentry_sdk-1.39.2-py2.py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 26.9 MB/s eta 0:00:00
# Collecting simplejson (from comet_ml>=3.31.19)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 16.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (2.0.7)
# Collecting websocket-client<1.4.0,>=0.55.0 (from comet_ml>=3.31.19)
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (1.14.1)
# Collecting wurlitzer>=1.0.2 (from comet_ml>=3.31.19)
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Collecting everett[ini]<3.2.0,>=1.0.1 (from comet_ml>=3.31.19)
#   Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml>=3.31.19)
#   Downloading dulwich-0.21.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (514 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 44.1 MB/s eta 0:00:00
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml>=3.31.19) (13.7.0)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml>=3.31.19)
#   Downloading configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml>=3.31.19) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml>=3.31.19) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml>=3.31.19) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml>=3.31.19) (0.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml>=3.31.19) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml>=3.31.19) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml>=3.31.19) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml>=3.31.19) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml>=3.31.19) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml>=3.31.19) (0.1.2)
# Installing collected packages: everett, wurlitzer, websocket-client, simplejson, sentry-sdk, semantic-version, python-box, dulwich, configobj, requests-toolbelt, comet_ml
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.7.0
#     Uninstalling websocket-client-1.7.0:
#       Successfully uninstalled websocket-client-1.7.0
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# Successfully installed comet_ml-3.37.0 configobj-5.0.8 dulwich-0.21.7 everett-3.1.0 python-box-6.1.0 requests-toolbelt-1.0.0 semantic-version-2.10.0 sentry-sdk-1.39.2 simplejson-3.19.2 websocket-client-1.3.3 wurlitzer-3.0.3
# Collecting datasets
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: dill, multiprocess, datasets
# Successfully installed datasets-2.16.1 dill-0.3.7 multiprocess-0.70.15

# %%
from datasets import Dataset, Value, ClassLabel, Features  #added

# %%
from sklearn.model_selection import train_test_split

# %%
training_data, validation_data = train_test_split(training_validation_data, test_size=0.05, random_state=10)

# %%
dataset_train = Dataset.from_pandas(training_data)
dataset_val = Dataset.from_pandas(validation_data)

# %%
categories = ['propagandistic', 'non_propagandistic']

# %%
new_features = dataset_train.features.copy()

# %%
new_features['text'] = Value('large_string')
new_features['propagandistic/non_propagandistic'] = ClassLabel(names=['propagandistic', 'non_propagandistic'])

# %%
dataset_train = dataset_train.cast(new_features)
dataset_val = dataset_val.cast(new_features)
# Out:
# Casting the dataset:   0%|          | 0/19735 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/1039 [00:00<?, ? examples/s]

# %%
dataset_train.features
# Out:
# {'text': Value(dtype='large_string', id=None),
#  'propagandistic/non_propagandistic': ClassLabel(names=['propagandistic', 'non_propagandistic'], id=None),
#  '__index_level_0__': Value(dtype='int64', id=None)}

# %%
dataset_val.features
# Out:
# {'text': Value(dtype='large_string', id=None),
#  'propagandistic/non_propagandistic': ClassLabel(names=['propagandistic', 'non_propagandistic'], id=None),
#  '__index_level_0__': Value(dtype='int64', id=None)}

# %% [markdown]
# #Training

# %%
from typing import Set, List, Tuple
from spacy.tokens import DocBin
import spacy
from tqdm.auto import tqdm

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"

locale.getpreferredencoding = getpreferredencoding

# %%
def convert_spacy_dataset(dataset, target_file: str, labels):
  nlp = spacy.blank("en")
  db = DocBin()

  for item in tqdm(dataset):
    try:
      doc = nlp.make_doc(item["text"])
      doc.cats = {label: 0 for label in labels}
      doc.cats[labels[item["propagandistic/non_propagandistic"]]] = 1

      db.add(doc)
    except:
      continue

  db.to_disk(target_file)
  return db

# %%
dataset_val
# Out:
# Dataset({
#     features: ['text', 'propagandistic/non_propagandistic', '__index_level_0__'],
#     num_rows: 1039
# })

# %%
convert_spacy_dataset(dataset_train, "train_data.spacy", categories)
convert_spacy_dataset(dataset_val, "validation_data.spacy", categories)
# Out:
#   0%|          | 0/19735 [00:00<?, ?it/s]
#   0%|          | 0/1039 [00:00<?, ?it/s]

# %%
# !python -m spacy init config --lang en --pipeline textcat_multilabel comet_config.cfg  #training model
# Out:
# 2024-01-26 03:27:02.749180: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-26 03:27:02.749241: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-26 03:27:02.750596: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-26 03:27:04.005111: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: en
# - Pipeline: textcat_multilabel
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# comet_config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train comet_config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
from spacy.cli.train import train as spacy_train

config_path = "comet_config.cfg"
output_model_path = "output_models/"

spacy_train(
    config_path,
    output_path=output_model_path,
    overrides={
        "paths.train": "train_data.spacy",
        "paths.dev": "validation_data.spacy",
    },
    use_gpu=0

)
# Out:
# ✔ Created output directory: output_models
# ℹ Saving to output directory: output_models
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['textcat_multilabel']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TEXTC...  CATS_SCORE  SCORE
# ---  ------  -------------  ----------  ------
#   0       0           0.25       63.18    0.63
#   0     200          43.20       91.73    0.92
#   0     400          30.59       93.52    0.94
#   0     600          28.42       95.08    0.95
#   0     800          23.64       96.15    0.96
#   0    1000          21.22       96.59    0.97
#   0    1200          18.56       96.97    0.97
#   0    1400          18.38       97.39    0.97
#   0    1600          16.18       97.67    0.98
#   1    1800          14.27       97.88    0.98
#   1    2000          12.48       98.07    0.98
#   1    2200          12.23       98.21    0.98
#   2    2400          11.11       98.38    0.98
#   2    2600           9.97       98.42    0.98
#   3    2800           9.00       98.54    0.99
#   3    3000           8.69       98.53    0.99
#   4    3200           8.36       98.58    0.99
#   4    3400           7.42       98.60    0.99
#   4    3600           7.65       98.63    0.99
#   5    3800           6.60       98.67    0.99
#   5    4000           6.79       98.73    0.99
#   6    4200           6.32       98.72    0.99
#   6    4400           6.10       98.75    0.99
#   7    4600           5.69       98.77    0.99
#   7    4800           5.64       98.73    0.99
#   8    5000           5.27       98.76    0.99
#   8    5200           5.05       98.81    0.99
#   9    5400           5.15       98.81    0.99
#   9    5600           4.72       98.82    0.99
#  10    5800           4.64       98.83    0.99
#  10    6000           4.55       98.84    0.99
#  10    6200           4.29       98.86    0.99
#  11    6400           3.93       98.85    0.99
#  11    6600           4.27       98.87    0.99
#  12    6800           3.96       98.84    0.99
#  12    7000           3.88       98.83    0.99
#  13    7200           3.80       98.83    0.99
#  13    7400           3.53       98.86    0.99
#  14    7600           3.49       98.83    0.99
#  14    7800           3.43       98.83    0.99
#  15    8000           3.32       98.83    0.99
#  15    8200           3.23       98.84    0.99
# ✔ Saved pipeline to output directory
# output_models/model-last

# %% [markdown]
# #Trial

# %%
trained_nlp = spacy.load("output_models/model-best/")

# %%
# !iconv -f UTF-8 -t ASCII dev_unlabeled.json
# Out:
# iconv: cannot open input file `dev_unlabeled.json': No such file or directory

# %%
json_open_trial = open("/content/drive/MyDrive/SemEval Task4/ar_subtask2b_test_unlabeled.json","r", encoding="utf-8")
json_load_trial = json.load(json_open_trial)

# %%
trial_data = json_load_trial
trial_data
# Out:
# [{'id': '00001',
#   'text': 'مشايخ الأوقاف واقفين لحماية المسجد\nحماية المسجد من الصلاة فيه',
#   'image': 'prop_meme_00001.jpg'},
#  {'id': '00002',
#   'text': 'المسؤولين العرب بعدما يخرو على شعبهم و حان الآن موعد إيجاد أي شيء لإرضاء الشعب القضية الفلسطينية\n',
#   'image': 'prop_meme_00002.jpg'},
#  {'id': '00003',
#   'text': 'عندما يسأل بوتفليقة عن المدة التي يريد قضاءها رنيسا للجزائر',
#   'image': 'prop_meme_00003.jpg'},
#  {'id': '00004',
#   'text': 'لا يعني انه اذا حطيت ايدي عليكي او اتطلعت ع صدرك  اكثر من مرة بالغلط او انه فتحت مواضيع جنسية قدامك انه انا متحرش لا ابدا كل ده أمور عادية بين الصحاب',
#   'image': 'prop_meme_00004.jpg'},
#  {'id': '00005',
#   'text': '*اسرائيل*\n*قتل وهدم واعتقالات\n* مستوطنات\n*ضم الضفة الغريبة \n*سرقه اموال الفلسطينين\nلسلطة الفلسطينية \nسنعيد النظر في علاقتنا مع الاسرائسليين',
#   'image': 'prop_meme_00005.jpg'},
#  {'id': '00006',
#   'text': 'القاضية عندها البيريود\nمحامى المتهم الي كسر إشارة المرور بيحاول يقنعها انها تخفف عقوبة الإعدام',
#   'image': 'prop_meme_00006.jpg'},
#  {'id': '00007',
#   'text': 'سوري بتفاخر انو بلدو فش فيها كورونا * تشيك*',
#   'image': 'prop_meme_00007.jpg'},
#  {'id': '00008',
#   'text': 'مواطن عربي\nالحكومة \nشيء بسيط من حقوقه\nالله يخليلنا الوطن وقائد  الوطن',
#   'image': 'prop_meme_00008.jpg'},
#  {'id': '00009',
#   'text': 'مكتوب هني ان جيسس يمشي عالماي\n شحقه يمشي عالماي سمجه اهوه ؟',
#   'image': 'prop_meme_00009.jpg'},
#  {'id': '00010',
#   'text': 'واحد صيني لسه طالع من الحجر الصحى',
#   'image': 'prop_meme_00010.jpg'},
#  {'id': '00011',
#   'text': '*دولة فقيرة على قد حالها لاقت شوية نفط *\n* الجيش الأمريكي*:\nاحنا  جايين نحميكم، فى دولة بدها تهجم عليكو ورح ينتاك أخت البلد إذا بنتدخلش تخافوش وي آرذ يونايتد ستيتس أف ايري',
#   'image': 'prop_meme_00011.jpg'},
#  {'id': '00012',
#   'text': '*عندما يكون المواطن الأردني التعيس في وسط ضحكه على نكات مظاهرة اللبنان ثم يتئكر بأن وضعه أسوء من اللبنانيين وأنه لو حاول النزول إلى الشارع للحصول على أبسط حقوقه فإن كل ما سيحصل عليه هو ضربة من عصا ذلك الدركي الأسمر*',
#   'image': 'prop_meme_00012.jpg'},
#  {'id': '00013',
#   'text': '- الخلايلة: بس عرفوا انه ما في صلاة عيد مع انه المساجد كانت مسكرة طول رمضان',
#   'image': 'prop_meme_00013.jpg'},
#  {'id': '00014',
#   'text': 'لما تتخيل فرص النجاح اللي قدامك بس بعدين تتذكر انك عايش بدوله عربيه',
#   'image': 'prop_meme_00014.jpg'},
#  {'id': '00015',
#   'text': 'عاشوراء\nسني \nملحد\nشيعي',
#   'image': 'prop_meme_00015.jpg'},
#  {'id': '00016',
#   'text': 'مشايخ الأوقاف واقفين لحماية المسجد\nحماية المسجد من الصلاة فيه',
#   'image': 'prop_meme_00016.jpg'},
#  {'id': '00017',
#   'text': 'لن تغرق سفينة انت قائدها',
#   'image': 'prop_meme_00017.jpg'},
#  {'id': '00018',
#   'text': 'الرجل الذي خاض شجار بالأيدي مع خاشقجي ',
#   'image': 'prop_meme_00018.jpg'},
#  {'id': '00019',
#   'text': 'هدا يفضل نايم لحد يوم الا متحان\nولما يسقط يقول النظام التعليمي الفاسد ضلمني',
#   'image': 'prop_meme_00019.jpg'},
#  {'id': '00020',
#   'text': 'السيسي\nالشعب المصري العريق',
#   'image': 'prop_meme_00020.jpg'},
#  {'id': '00021',
#   'text': 'مصر\nاسرائيل منشغلة بالاحتفال باعيادها في تشرين من عام 1973 \nسوريا ',
#   'image': 'prop_meme_00021.jpg'},
#  {'id': '00022',
#   'text': '* لما تكون جندي أجنبي ويبعثوك تقاتل في سوريا وهناك تلاقيهم بطخو عليكو وهم لابسين جينز وصنادل ونص كم *:',
#   'image': 'prop_meme_00022.jpg'},
#  {'id': '00023',
#   'text': 'لما تروح تستثمر مصاري الدعم الي جاييتك بانشاء مزارع فقوس وخيار بالسودان',
#   'image': 'prop_meme_00023.jpg'},
#  {'id': '00024',
#   'text': 'لنفترض ان عدد النسويات 163569463\nتجاهلهم كما تجاهلت العدد',
#   'image': 'prop_meme_00024.jpg'},
#  {'id': '00025',
#   'text': 'الفيمنست عندما تقع في الحب\nسأحلق إبطي من أجلك',
#   'image': 'prop_meme_00025.jpg'},
#  {'id': '00026',
#   'text': 'الحكومة بتحاول تزبط منحة من الكويت\nالجمهور الاردني بهتف لصدام بمباراة الكويت',
#   'image': 'prop_meme_00026.jpg'},
#  {'id': '00027',
#   'text': 'اجمل فيمينست \nاقل واحده بتدافع عن الرجاله ',
#   'image': 'prop_meme_00027.jpg'},
#  {'id': '00028',
#   'text': 'وزير التعليم :\nاي سؤال متعرفش إجابته اكتب السيسي هتاخد نص الدرجة',
#   'image': 'prop_meme_00028.jpg'},
#  {'id': '00029',
#   'text': 'MBC\nمسلسل الهيبة\nالعرب',
#   'image': 'prop_meme_00029.jpg'},
#  {'id': '00030',
#   'text': 'عندما تكرس حياتك في صناعة الميمز من أجل إضحاك الآخرين ثم تقوم في أحد الأيام بنشر ميم عنصرية ويبدأ الجميع بمهاجمتك\nعندما تتضايقون مني يوما \nتذكروا كم يؤما أسعدتكم فيه\n وشكرا يالنكارين',
#   'image': 'prop_meme_00030.jpg'},
#  {'id': '00031',
#   'text': 'شيوخ الفيسبوك بعد الكريسماس',
#   'image': 'prop_meme_00031.jpg'},
#  {'id': '00032',
#   'text': 'بهذه المفومة سوف تسمولاقصى دوجات الإيمان',
#   'image': 'prop_meme_00032.jpg'},
#  {'id': '00033',
#   'text': 'أمور يجهلها الرجال عن النساء \nدليل إرشادات غسالة الأطباق ',
#   'image': 'prop_meme_00033.jpg'},
#  {'id': '00034',
#   'text': 'نضال الفيمنست وهي فاتحة نت \nفاتحة نت من اختراع الذكور من جهاز اخترعه الذكور في موقع تواصل اجتماعي ابتكره الذكور وعلى أثاث من صنع الذكور وبتكلفة دفع تمنها أبوها الذكر عشان تشتم الذكور',
#   'image': 'prop_meme_00034.jpg'},
#  {'id': '00035',
#   'text': 'المراة هتستفزك بانوثتها وجمالها\nاحذر اخي\nالمراة خدعة والحب الحقيقي هو الهوميز',
#   'image': 'prop_meme_00035.jpg'},
#  {'id': '00036',
#   'text': 'فلتر القدس على بروفايل الفيسبوك\nالعرب\nصفقة القرن',
#   'image': 'prop_meme_00036.jpg'},
#  {'id': '00037',
#   'text': 'شباب بشعر كهذا لديهم إمكانية بنسبة ١٢٥% من سرقة أرضك',
#   'image': 'prop_meme_00037.jpg'},
#  {'id': '00038',
#   'text': 'حلول جذرية للمشاكل المالية\nقانون ضريبة جديد وفع الاسعار',
#   'image': 'prop_meme_00038.jpg'},
#  {'id': '00039',
#   'text': 'كفاية خوف من المجتمع\nعندي الوالدة تقشرلي الرمان',
#   'image': 'prop_meme_00039.jpg'},
#  {'id': '00040',
#   'text': 'ستيفن هوكينغ: لا يوجد دليل على وجود الله\nوهالأدلة القاطعة \nربي أغفرلي إني كنت من الظالمين',
#   'image': 'prop_meme_00040.jpg'},
#  {'id': '00041',
#   'text': 'ماكروغر \nحبيب \nدريك \nالعرب : سبو دينه فانظر ماذا فعل\nلاي لاي لاي لاي',
#   'image': 'prop_meme_00041.jpg'},
#  {'id': '00042',
#   'text': 'البنات: هرجع بالزمن عشان ارتبط بالكس تاني \nالولاد:- \nيا رسول الله أنا في ضهرك',
#   'image': 'prop_meme_00042.jpg'},
#  {'id': '00043',
#   'text': 'متخفش يا صاحبي دي مش عالمة أحياء\nدي المرأة المصرية بتبحث عن افضل طريقة تتطلق من زوجها وتسرق منه أولاده وفلوسه',
#   'image': 'prop_meme_00043.jpg'},
#  {'id': '00044',
#   'text': 'لنفرض أنك ذهبت الى السفارة السعودية\nأليس تخرج قطعة قطعة ؟',
#   'image': 'prop_meme_00044.jpg'},
#  {'id': '00045',
#   'text': 'البنت لما يكون في مسافة 100 متر\n اقرب اوبر يروحي\nالولد لما يكون في مسافة 2 كيلو \nهتمشاها مش مستاهلة مواصله',
#   'image': 'prop_meme_00045.jpg'},
#  {'id': '00046',
#   'text': 'غلاء معيشة \nارتفاع  اسعار\n سوء البنية التحتية\nالحكومة + النواب\nالمواطن السحيج',
#   'image': 'prop_meme_00046.jpg'},
#  {'id': '00047',
#   'text': 'لابتعرف تطبخ .. ولا تغسل .. ونكد ليل نهار ومسلسلات هندى بال 400 حلقة\nطلقتها ',
#   'image': 'prop_meme_00047.jpg'},
#  {'id': '00048',
#   'text': 'ودي احطها فين يا ريس',
#   'image': 'prop_meme_00048.jpg'},
#  {'id': '00049',
#   'text': 'لما تنجح بمادة\nانت مطبل فيها !',
#   'image': 'prop_meme_00049.jpg'},
#  {'id': '00050',
#   'text': 'نعم للفساد... لا للإصلاح!!!\nمرشحكم الدكتور \nعيسى العمرو',
#   'image': 'prop_meme_00050.jpg'},
#  {'id': '00052',
#   'text': 'بتحس انومرتك متحكمة فيك\nلأمابحس',
#   'image': 'prop_meme_00052.jpg'},
#  {'id': '00053',
#   'text': 'مناضلات يطالبن بنزع الحجاب تحت شعار من حق المرأة أن تظهر جمالها',
#   'image': 'prop_meme_00053.jpg'},
#  {'id': '00054',
#   'text': 'تماثيل آلهة الإغريق\nأصنام آله العرب  العرب\nالعرب حتى بالكفر ذوقهم خرا',
#   'image': 'prop_meme_00054.jpg'},
#  {'id': '00055',
#   'text': 'يوم اتحدوا العرب ...\nقصفوا اليمن',
#   'image': 'prop_meme_00055.jpg'},
#  {'id': '00056',
#   'text': 'صنع للقتل\nصنع للفتنة\nوالفتنة أشد من القتل',
#   'image': 'prop_meme_00056.jpg'},
#  {'id': '00057',
#   'text': 'اخي الجوهرة انت من تختار من تكون',
#   'image': 'prop_meme_00057.jpg'},
#  {'id': '00058',
#   'text': 'مستوطنون يحرقون منزلا في قرية دوما جنوب مدينة # نابلس مما ادى الى استشهاد طفل (سنة ونصف ) واصابة عائلته بجروح خطيرة\nرد القيادة الفلسطينية\nشايف كل هدول ؟!\nبكرهوك!',
#   'image': 'prop_meme_00058.jpg'},
#  {'id': '00060',
#   'text': 'المعلمة: ما هولا شيء\n تلميذ إسراليلى: أنا أنا أنا!\nالمعلمة: أحسنت وماذا أيضا ',
#   'image': 'prop_meme_00060.jpg'},
#  {'id': '00061',
#   'text': 'أكثر علمين ما لهم أي أهمية في الحياة:',
#   'image': 'prop_meme_00061.jpg'},
#  {'id': '00071',
#   'text': 'شخص غني ومستقر ماديا\nالشيوعيون',
#   'image': 'prop_meme_00071.jpg'},
#  {'id': '00073',
#   'text': 'عندما تدفع امول الضرائب من اجل تمويل مشروع مركبة تشالنجر لوكالة الفضاء الأمريكية ناسا من أجل التفاخر أمام العالم لكن المركبة تنفجر قبل اختراقها لطبقة التروبوسفير المواطن الأمريكي',
#   'image': 'prop_meme_00073.jpg'},
#  {'id': '00076',
#   'text': 'بلاش العشم\n والثقه الزياده وانت بتقول \n"ان توبنكز أحلي من الهوهوز"\n استحاله  تكون أحلي لأن الحياه اثبتت انها والله ما فيه  أحلي من الهوهوز',
#   'image': 'prop_meme_00076.jpg'},
#  {'id': '00077',
#   'text': 'المصريين \nزودلي توميه يا معلم\n الاتراك واللبنايين\n إمشو من البلد حرام عليكو أخدتو وظايفنا وقطعتو علينا في لقمه عيشنا\n',
#   'image': 'prop_meme_00077.jpg'},
#  {'id': '00078',
#   'text': 'لما يشلوك الإصلاحيين المسبح و انت جاهل فكتبر و تصبح " شاب تعلق قلبه بالمسابح "\n و تظهر في سهيل\n',
#   'image': 'prop_meme_00078.jpg'},
#  {'id': '00079',
#   'text': '*الحوثيين يحتفلون بيوم الغدير\nتهامة تغرق الشعب  بدون رواتب البنية التحتية تنهار\n\n',
#   'image': 'prop_meme_00079.jpg'},
#  {'id': '00080',
#   'text': '*نسوي ذكر*\nأصحابي جايين يلعبوا في البيت\n* أمه *\nيلعبوا بلايستيشن صح؟\nيلعبوا بلايستيشن صح؟',
#   'image': 'prop_meme_00080.jpg'},
#  {'id': '00081',
#   'text': 'صاحبي الضالعي وهو يقنعنا\nان ارضيتنا من حقه لانه ابن خاله مات وهو يقاتل الحوثي في الحديدة',
#   'image': 'prop_meme_00081.jpg'},
#  {'id': '00082',
#   'text': 'هل صحيح انك ك صيدلي يمني بدئت تعمل ابحاث عن فيروس كورونا ؟\nولله مانا داري خليني اخزن',
#   'image': 'prop_meme_00082.jpg'},
#  {'id': '00083',
#   'text': 'المؤسسة العامة للكهرباء\nإحنا قطعنا عليكم الكهربا كإجراء احترازي عند نزول الأمطار والعواصف للرعدية لضمان سلامتكم\nالشعب\nزينة والله زينة\nدنتو لقطا\n',
#   'image': 'prop_meme_00083.jpg'},
#  {'id': '00084',
#   'text': 'اهداف الثورة اليمنية\nاهداف بلا هدف',
#   'image': 'prop_meme_00084.jpg'},
#  {'id': '00085',
#   'text': '*اليمن*\nالسعودية\nاتفضلو مساعدات تمرسكري درجة اولى\n*اليمن*\nالسعودية\nتمر ايش ؟\nمحتاجين خدمات زي الكهرباء والماء \n*اليمن*\nالسعودية\nمشوحالكم بالتمر نوعية كويسة والله\n',
#   'image': 'prop_meme_00085.jpg'},
#  {'id': '00087',
#   'text': 'انهيار الريال اليمني والسلع الغذائية تشهد ارتفاع \nجنوني\nتاني ، ارتفاع تاني! \nالبيض قده الحبة ب 90 ريال\n',
#   'image': 'prop_meme_00087.jpg'},
#  {'id': '00088',
#   'text': 'بموت:\n ههههههههههههههههههههههههههههههههههه\nفيفى \nعبدو \nشذى \nحسون',
#   'image': 'prop_meme_00088.jpg'},
#  {'id': '00089',
#   'text': 'رئيس فرنسا\nيتراجع عن زيادة اسعار الوقود\nعيل طري',
#   'image': 'prop_meme_00089.jpg'},
#  {'id': '00090',
#   'text': 'المدنى دايما بيشيل الليلة\n# استرها_ معانا _ يا رب\nالعمال مش لابسين كمامات ليه ؟\n فين المدنى اللى هنا ؟ \nبيسأل عليا. بيسأل عليا  ',
#   'image': 'prop_meme_00090.jpg'},
#  {'id': '00091',
#   'text': 'لما عيد ميلاد الناس اللي ف شهر واحد واتنين ميبقاش فيه امتحانات ويبقي ف شهر 3\n*مواليد شهر 3* \n*مواليد شهر1.2*\nالي علي وشك د٥ انا عيشت فيه سنين',
#   'image': 'prop_meme_00091.jpg'},
#  {'id': '00092',
#   'text': 'هنرجع لأيام زمان أرن عليك رنة تعرف أن أنا نزلت رنتين تعرف أني وصلت\nتفتح عليا\nأقسم بالله لأشيلك من على وش الأرض',
#   'image': 'prop_meme_00092.jpg'},
#  {'id': '00093',
#   'text': 'أخبارك\nمصطفى مدبولي\n أنا  وزملائى الوزراء لا ننام لتحسين معيشة المواطن\nناموا انتوا بس و المعيشه هتتحسن لوحدها',
#   'image': 'prop_meme_00093.jpg'},
#  {'id': '00094',
#   'text': 'الطالب اللي حرارته هتزيد هنديله  لبوس في اللجنة \nأعملى كمدات الأول طيب',
#   'image': 'prop_meme_00094.jpg'},
#  {'id': '00095',
#   'text': 'قبل الوقفة وزحمتها والناس مشغولة بلحمتها\nوسرعة النت لسه ببركتها حبيت اعيد على احلى حبتها \nكفاية  رسايل من دي ابوس ايدك علاقتنا ببعض هتبوظ بسببها',
#   'image': 'prop_meme_00095.jpg'},
#  {'id': '00096',
#   'text': 'انت يرضيك يا حضرت واحدة تسيب جوزها يروح الشغل كل يوم الصبح من غير فطار؟ \nانتوا بتفطروا كل بوم؟؟',
#   'image': 'prop_meme_00096.jpg'},
#  {'id': '00097',
#   'text': 'المسيحين بيعيدو والمسلمين بيعيدو\nنعمل ضريبة على الأعياد بقا',
#   'image': 'prop_meme_00097.jpg'},
#  {'id': '00099',
#   'text': 'أبعد يا حب ابعد بقولك لأه ، لأه بقولك ..اقسم بالله بالشبشب',
#   'image': 'prop_meme_00099.jpg'},
#  {'id': '00100',
#   'text': 'لما يقولك إنتي تعبانه طول النهار خشي نامي وإرتاحي إعرفي إن التانيه أونلاين',
#   'image': 'prop_meme_00100.jpg'},
#  {'id': '00101',
#   'text': 'وأكلم مين لما أحب أخاطب الشعب المصر ي.. ؟!\nكلم أي حد من المنوفية',
#   'image': 'prop_meme_00101.jpg'},
#  {'id': '00109',
#   'text': 'ورني الشخص اللي مغنيك عن كل الناس ويسوى عيونك(@)؟',
#   'image': 'prop_meme_00109.jpg'},
#  {'id': '00110',
#   'text': 'انت بتمسك الموبايل كتير اوي ع فكره \nا٥ م هو بتاعي',
#   'image': 'prop_meme_00110.jpg'},
#  {'id': '00111',
#   'text': 'بيقدم على وظيفة وطالبين مه صورة بخلفية بيضاء',
#   'image': 'prop_meme_00111.jpg'},
#  {'id': '00112',
#   'text': '\nاحنا متمسكين بالدراسه والعلم والشهادات لانها الشي الوحيد الي بيطلعنا من الشرق الاوسخ',
#   'image': 'prop_meme_00112.jpg'},
#  {'id': '00116',
#   'text': 'لا تكثروا في الردود علي الكو منتات فإنها تؤدي الي الماسينجر ومنه الي الواتس والعياذ بالله',
#   'image': 'prop_meme_00116.jpg'},
#  {'id': '00117',
#   'text': 'وقالوا عنيده وقويه مبيأثرش شئ فيها..',
#   'image': 'prop_meme_00117.jpg'},
#  {'id': '00118',
#   'text': 'قولتلها :انا معجب بيكى..\n قالتلى : كلمني عن مستقبلك، قو لتلها كلميني عن ماضيكي ، قالتلي إن الله غفور رحيم قولتلها  !ن الله رزاق كريم',
#   'image': 'prop_meme_00118.jpg'},
#  {'id': '00119',
#   'text': 'ايه دة انت بتصلي ؟\nاه عادي هوانت كنت فاكرني بعبد علبة تونة منا مسلم وموحد بالله',
#   'image': 'prop_meme_00119.jpg'},
#  {'id': '00120',
#   'text': 'سنبلغُ حُلمنا لوبعد حِين \nفنحنُ بِحارُعزم إن أردنا\n',
#   'image': 'prop_meme_00120.jpg'},
#  {'id': '00121',
#   'text': 'لما أمسك الكتاب 3 دقايق علي بعض من غيرما أفتح التليفون .\nجايلكو يا شوية اوائل',
#   'image': 'prop_meme_00121.jpg'},
#  {'id': '00125',
#   'text': 'يا حيوان يا كلب هتخلص النت\n',
#   'image': 'prop_meme_00125.jpg'},
#  {'id': '00127',
#   'text': 'الواحد وهو رايح الشغل يوم الاحد\n ربنا يتوب علينا...',
#   'image': 'prop_meme_00127.jpg'},
#  {'id': '00128',
#   'text': 'انا مش مزاكره حاجه وشكلي هسقط ايه للي انا بعمله في نفسي ده بس ياربي\nسعديه شكري عبدالرحمن 99.9 الاولي ع المجره',
#   'image': 'prop_meme_00128.jpg'},
#  {'id': '00129',
#   'text': 'أجنبية فاجأها الطلق أثناء السباحة فى دهب فقام والدها وزوجها بتوليدها تحت الماء وخرجت من البحر بمنتهى البساطة\nسامعة ياللي راقدة عند أمك من الشهر التاني',
#   'image': 'prop_meme_00129.jpg'},
#  {'id': '00130',
#   'text': 'نزلت الكمامة من ع  مناخيري شوية عشان اتخنقت ومش قادرة أخد نفسي اللي بتراقب علينا:\nالطالبة اللي نزلت الكما ما ا ا ا ا ا ا ا اه',
#   'image': 'prop_meme_00130.jpg'},
#  {'id': '00131',
#   'text': 'إلى زوجتي المستقبلية ..سأجعلك تزورين هذا القسم كل سنة ',
#   'image': 'prop_meme_00131.jpg'},
#  {'id': '00132',
#   'text': 'وانا واقفه بتفرج علي الشقه بعد مشلت السجاد وكركبت الدنيا للعيد',
#   'image': 'prop_meme_00132.jpg'},
#  {'id': '00133',
#   'text': 'منزعقش للطفل قبل النوم عشان ميأثرش على صحته النفسية \n= انا وابني قبل النوم',
#   'image': 'prop_meme_00133.jpg'},
#  {'id': '00135',
#   'text': 'Youssef Amon \nمبدئيا كده لو جالي كورونا هتف في النيل',
#   'image': 'prop_meme_00135.jpg'},
#  {'id': '00136',
#   'text': 'كل ضحكه ب مقابل \nبلاستيشن 5 ذبحني\n',
#   'image': 'prop_meme_00136.jpg'},
#  {'id': '00137',
#   'text': 'ايه ده انتى تخنتى كده ليه ؟\n = عشان مباكلش ف نفسى زيك ..',
#   'image': 'prop_meme_00137.jpg'},
#  {'id': '00138',
#   'text': 'يعني احنا هنسيب كل الشباب الحلوه دي !\nوهنتجوز واحد بس !',
#   'image': 'prop_meme_00138.jpg'},
#  {'id': '00139',
#   'text': '-هتعرف تستعمله وتعمل البحث لوحدك \n*السؤال د٥ لو اتكرر هاكل ودانك دي* \n*تعالي شغلهولي*',
#   'image': 'prop_meme_00139.jpg'},
#  {'id': '00140',
#   'text': 'عندنا اللي ترفض عريس يقولوا ماشيه مع واحد تاني\n = طب اللي بتوافق؟\nتبقى ماشيه معاه',
#   'image': 'prop_meme_00140.jpg'},
#  {'id': '00145',
#   'text': 'العلماء : لايمكن سماع الصورة\nالصورة',
#   'image': 'prop_meme_00145.jpg'},
#  {'id': '00146',
#   'text': '-هو دا وزير التربية والتعليم ؟ \n*اه\n -انا عايز فلوسى عشان انا ولا اتربيت ولا اتعملت',
#   'image': 'prop_meme_00146.jpg'},
#  {'id': '00147',
#   'text': 'انا جاهزه\nوداعا للغرق مع طقم العوامات الخماسيه',
#   'image': 'prop_meme_00147.jpg'},
#  {'id': '00148',
#   'text': 'ناس تتعب وناس تاخد اللقطه',
#   'image': 'prop_meme_00148.jpg'},
#  {'id': '00149',
#   'text': 'الناس بتمتحن وانا بحط روج مانا مش هبئا سقوطه وكمان شكلي وحش ..\n',
#   'image': 'prop_meme_00149.jpg'},
#  {'id': '00150',
#   'text': 'افشل ٣ مشاريع فى حياتي:\n الدايت\n انام قبل الساعه ١٢\n احوش فلوس',
#   'image': 'prop_meme_00150.jpg'},
#  {'id': '00151',
#   'text': 'لما نبقي متخانقين وانا اللي غلطانه ومش لاقياله مبررللي انا عملته\nاحنا محسودين',
#   'image': 'prop_meme_00151.jpg'},
#  {'id': '00152',
#   'text': 'جالنا ضيوف وماما مش موجوده فى البيت وبابا قالى ادخلى اعمليلنا حاجه:\n*انا لما ادخل المطبخ*\n',
#   'image': 'prop_meme_00152.jpg'},
#  {'id': '00153',
#   'text': 'الناس ال عملت الحركة دى وهيا صغيره تعمل لايك عشان بنعمل جرد للجماعة تافهين',
#   'image': 'prop_meme_00153.jpg'},
#  {'id': '00159',
#   'text': 'واحد لسه خاطب جديد وراح يقعد مع خطيبته شويه\nخطيبته:\nتليفوني اتكسر',
#   'image': 'prop_meme_00159.jpg'},
#  {'id': '00168',
#   'text': 'المنوفي لما يعرف ان الجنيه بيجي بطلوع الروح',
#   'image': 'prop_meme_00168.jpg'},
#  {'id': '00170',
#   'text': 'الكو تيين 2020 المصريين ليسوا شركائنا فالوطن وهم هنا لخدمتنا\nعمي مبارك الحقني عمي مبارك ',
#   'image': 'prop_meme_00170.jpg'},
#  {'id': '00175',
#   'text': 'الشوارع كلها علقت زينه رمضان\nشارعنا :',
#   'image': 'prop_meme_00175.jpg'},
#  {'id': '00183',
#   'text': 'تخيل صعوبة الحياة عندما تكون اغبى من الحمامة',
#   'image': 'prop_meme_00183.jpg'},
#  {'id': '00200',
#   'text': '%90 من الطلاب يحضرون المحاضرات الاونلاين *الطلاب*',
#   'image': 'prop_meme_00200.jpg'},
#  {'id': '00222',
#   'text': 'شخص لم يعطه الله اي موهبه',
#   'image': 'prop_meme_00222.jpg'},
#  {'id': '00244',
#   'text': 'ابعدي عن الراجل يا خطافة الرجالااااو',
#   'image': 'prop_meme_00244.jpg'},
#  {'id': '00275',
#   'text': 'فرنسا تسجيل إصابات جديدة بفيروس كورونا منه حالتان عادتا من مصر\nوزارة الصحة المصرية : إلهي تنفضح !',
#   'image': 'prop_meme_00275.jpg'},
#  {'id': '00277',
#   'text': 'من باعنا خسر دلعنا\nلالاانا مسمحلكيش دا انتي كنتى نكدية بنت كلب',
#   'image': 'prop_meme_00277.jpg'},
#  {'id': '00318',
#   'text': 'طبيبة مصرية تشفى مرضاها بالاحتضان والعناق \nلأ ده احنا نروح نتعالج بقى',
#   'image': 'prop_meme_00318.jpg'},
#  {'id': '00321',
#   'text': 'هتعرف تترجم الفيلم يا بسيوني ؟\nشوف يا باشا هفاجئك \nيا اللى عالترعة حود المالح! ',
#   'image': 'prop_meme_00321.jpg'},
#  {'id': '00322',
#   'text': 'بجد نفسي ارتبط  بواحد زيك\nأنا زيي',
#   'image': 'prop_meme_00322.jpg'},
#  {'id': '00323',
#   'text': 'أنا معرفش أنا بفتحك لية أصلاً \nمعرفش إية سر حبى فيك وفى فتحك كل شوية مدام مفيش حال بيعبرني',
#   'image': 'prop_meme_00323.jpg'},
#  {'id': '00324',
#   'text': 'انا واخويا لماكنا نعمل عشا خفيف بالليل بعد ماكل اللي في البيت يناموا',
#   'image': 'prop_meme_00324.jpg'},
#  {'id': '00325',
#   'text': 'لا مفيش جواز دلوقتي بنتنا لسة هبلة\n=...',
#   'image': 'prop_meme_00325.jpg'},
#  {'id': '00326',
#   'text': 'انا رايح اعوم لحد البراميل دي\nملناش دعوة',
#   'image': 'prop_meme_00326.jpg'},
#  {'id': '00327',
#   'text': 'انا كنت فاكر ان في شيطان قذر مسيطرعلينا طول السنه\n\nطلع الواحد اصلا قذر وظالم الشيطان معاه',
#   'image': 'prop_meme_00327.jpg'},
#  {'id': '00354',
#   'text': 'الله يرحمك يا جدي.. كنت حرامي وكمان كداب\nالصين حلوة',
#   'image': 'prop_meme_00354.jpg'},
#  {'id': '00368',
#   'text': 'سوسو صاحبتى قالتلى على عيوبك اللى مكنتش شايفها فيك يا خاين يا غشاش يا حقير ياوحش\n*صاحبتها*\nبحبك',
#   'image': 'prop_meme_00368.jpg'},
#  {'id': '00369',
#   'text': 'سيتم إلغاء الفصل الدراسي الثاني قي حال اندلاع اعمال عنف \nإذا هي الحرب',
#   'image': 'prop_meme_00369.jpg'},
#  {'id': '00373',
#   'text': 'لما البس هدوم العيدومعرفش هروح بيها فين',
#   'image': 'prop_meme_00373.jpg'},
#  {'id': '00374',
#   'text': 'من هنادى عليك علشان تاكل تاني عنك مكلت\nي ابني قوم كل',
#   'image': 'prop_meme_00374.jpg'},
#  {'id': '00375',
#   'text': 'جاهزون يا اطفال\nهاي هاي كابتن\nوالنبي يعوض عليا',
#   'image': 'prop_meme_00375.jpg'},
#  {'id': '00376',
#   'text': 'يا بنتي كل دة نوم قومي اقعدي معانا شوية!! \nانا\nفي ايه باخد قيلولة يومين كدة',
#   'image': 'prop_meme_00376.jpg'},
#  {'id': '00399',
#   'text': 'الزوجة اذا عرفت ان راتب زوجها نزل',
#   'image': 'prop_meme_00399.jpg'},
#  {'id': '00426',
#   'text': 'لما تخش على جروب الدفعة\nيهود الدفعة:\nانا خلصت الأبحاث ياجماعة سهلة جدا',
#   'image': 'prop_meme_00426.jpg'},
#  {'id': '00428',
#   'text': 'الصين تعلن وفاة أول حالة مصابة بفايروس "Hantavirus"\n\nبقولك إيه ما تديها نووي وتخلصنا',
#   'image': 'prop_meme_00428.jpg'},
#  {'id': '00431',
#   'text': '*انت*\nانت مبقتش بتذاكرليه يا فاشل\n طب لو سمحت متقوليش يا فاشل\nبتتضايق من يا فاشل\nطب يا فاشل يافاشل يا فاااشل',
#   'image': 'prop_meme_00431.jpg'},
#  {'id': '00447',
#   'text': 'لقد انشغلت بك فى حلمى طوال ليلة البارحة\nكيف رأيتنى ؟\nعديم التربية',
#   'image': 'prop_meme_00447.jpg'},
#  {'id': '00460',
#   'text': '\nان الزواج يااخواني مشروع فاااااااشل \n\nGot Engaged Today\n\nهيبقي شبهي وشبهك هيبقى عمري وعمرك',
#   'image': 'prop_meme_00460.jpg'},
#  {'id': '00472',
#   'text': 'كوريا  الشمالية تعلن عن اكتشافها علاج لل "إيدز "و"إيبولا"\n',
#   'image': 'prop_meme_00472.jpg'},
#  {'id': '00479',
#   'text': '\n*صاحبك*\nإنت اللي قولتلى لازم نجتهد عشان ننجح ونطلع من الاوائل\n\n*إنت*\nتقوم تكلم المدرسين عشان نبدأ دروس يا غبي',
#   'image': 'prop_meme_00479.jpg'},
#  {'id': '00482',
#   'text': 'لما اكون قاعدة مع ناس واسمع وحده بتحكي حوار غلط انا عارفة الصح ..\nمليش دعوة\nمليش دعوة\n مليش دعوة \nمليش دعوة\n مليش دعوة \nمليش دعوة\n مليش دعوة',
#   'image': 'prop_meme_00482.jpg'},
#  {'id': '00483',
#   'text': 'كل الناس اكراشت و ارتبطت في 2017\nالا انا و انتي يانحس يانحس',
#   'image': 'prop_meme_00483.jpg'},
#  {'id': '00490',
#   'text': 'لازم تسامح ال ظلمك عشان احنا في ايام مفترجه\nكلام يحترم وكل حاجه بس ربنا يخدهم',
#   'image': 'prop_meme_00490.jpg'},
#  {'id': '00491',
#   'text': 'الصين تتعافي تماما من الكورونا وتحذر شعبها من السفر للدول الموبوءة..',
#   'image': 'prop_meme_00491.jpg'},
#  {'id': '00499',
#   'text': 'هذا القط حياته بائسه جدا وفقيرلايملك ربع تونه💔\n',
#   'image': 'prop_meme_00499.jpg'},
#  {'id': '00506',
#   'text': '| هى كورونا دى داجل ولا ست\n والله يابنتى طالما منكده على العالم كله يبقي اكيد وست الستات كمان😂😂',
#   'image': 'prop_meme_00506.jpg'},
#  {'id': '00541',
#   'text': 'بتضرب أعز أصحابك مقابل مليون دولار؟؟\nأنا:',
#   'image': 'prop_meme_00541.jpg'},
#  {'id': '00542',
#   'text': 'ولادي بعد ما تنمرت على نص الكوكب',
#   'image': 'prop_meme_00542.jpg'},
#  {'id': '00573',
#   'text': 'لما تتأخر بالرجعة عالبيت وابوك يقلك وينك لهلأ  يا كلب:\n',
#   'image': 'prop_meme_00573.jpg'}]

# %%
# !pip install -U deep-translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 849.3 kB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (4.11.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2023.11.17)
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4

# %%
from deep_translator import GoogleTranslator

# %%
langs_dict = GoogleTranslator().get_supported_languages(as_dict=True)
langs_dict
# Out:
# {'afrikaans': 'af',
#  'albanian': 'sq',
#  'amharic': 'am',
#  'arabic': 'ar',
#  'armenian': 'hy',
#  'assamese': 'as',
#  'aymara': 'ay',
#  'azerbaijani': 'az',
#  'bambara': 'bm',
#  'basque': 'eu',
#  'belarusian': 'be',
#  'bengali': 'bn',
#  'bhojpuri': 'bho',
#  'bosnian': 'bs',
#  'bulgarian': 'bg',
#  'catalan': 'ca',
#  'cebuano': 'ceb',
#  'chichewa': 'ny',
#  'chinese (simplified)': 'zh-CN',
#  'chinese (traditional)': 'zh-TW',
#  'corsican': 'co',
#  'croatian': 'hr',
#  'czech': 'cs',
#  'danish': 'da',
#  'dhivehi': 'dv',
#  'dogri': 'doi',
#  'dutch': 'nl',
#  'english': 'en',
#  'esperanto': 'eo',
#  'estonian': 'et',
#  'ewe': 'ee',
#  'filipino': 'tl',
#  'finnish': 'fi',
#  'french': 'fr',
#  'frisian': 'fy',
#  'galician': 'gl',
#  'georgian': 'ka',
#  'german': 'de',
#  'greek': 'el',
#  'guarani': 'gn',
#  'gujarati': 'gu',
#  'haitian creole': 'ht',
#  'hausa': 'ha',
#  'hawaiian': 'haw',
#  'hebrew': 'iw',
#  'hindi': 'hi',
#  'hmong': 'hmn',
#  'hungarian': 'hu',
#  'icelandic': 'is',
#  'igbo': 'ig',
#  'ilocano': 'ilo',
#  'indonesian': 'id',
#  'irish': 'ga',
#  'italian': 'it',
#  'japanese': 'ja',
#  'javanese': 'jw',
#  'kannada': 'kn',
#  'kazakh': 'kk',
#  'khmer': 'km',
#  'kinyarwanda': 'rw',
#  'konkani': 'gom',
#  'korean': 'ko',
#  'krio': 'kri',
#  'kurdish (kurmanji)': 'ku',
#  'kurdish (sorani)': 'ckb',
#  'kyrgyz': 'ky',
#  'lao': 'lo',
#  'latin': 'la',
#  'latvian': 'lv',
#  'lingala': 'ln',
#  'lithuanian': 'lt',
#  'luganda': 'lg',
#  'luxembourgish': 'lb',
#  'macedonian': 'mk',
#  'maithili': 'mai',
#  'malagasy': 'mg',
#  'malay': 'ms',
#  'malayalam': 'ml',
#  'maltese': 'mt',
#  'maori': 'mi',
#  'marathi': 'mr',
#  'meiteilon (manipuri)': 'mni-Mtei',
#  'mizo': 'lus',
#  'mongolian': 'mn',
#  'myanmar': 'my',
#  'nepali': 'ne',
#  'norwegian': 'no',
#  'odia (oriya)': 'or',
#  'oromo': 'om',
#  'pashto': 'ps',
#  'persian': 'fa',
#  'polish': 'pl',
#  'portuguese': 'pt',
#  'punjabi': 'pa',
#  'quechua': 'qu',
#  'romanian': 'ro',
#  'russian': 'ru',
#  'samoan': 'sm',
#  'sanskrit': 'sa',
#  'scots gaelic': 'gd',
#  'sepedi': 'nso',
#  'serbian': 'sr',
#  'sesotho': 'st',
#  'shona': 'sn',
#  'sindhi': 'sd',
#  'sinhala': 'si',
#  'slovak': 'sk',
#  'slovenian': 'sl',
#  'somali': 'so',
#  'spanish': 'es',
#  'sundanese': 'su',
#  'swahili': 'sw',
#  'swedish': 'sv',
#  'tajik': 'tg',
#  'tamil': 'ta',
#  'tatar': 'tt',
#  'telugu': 'te',
#  'thai': 'th',
#  'tigrinya': 'ti',
#  'tsonga': 'ts',
#  'turkish': 'tr',
#  'turkmen': 'tk',
#  'twi': 'ak',
#  'ukrainian': 'uk',
#  'urdu': 'ur',
#  'uyghur': 'ug',
#  'uzbek': 'uz',
#  'vietnamese': 'vi',
#  'welsh': 'cy',
#  'xhosa': 'xh',
#  'yiddish': 'yi',
#  'yoruba': 'yo',
#  'zulu': 'zu'}

# %%
for utterance in trial_data:
  utterance["text"] = GoogleTranslator(source='ar', target='en').translate(utterance["text"])

# %%
trial_data
# Out:
# [{'id': '00001',
#   'text': 'Endowment sheikhs stand to protect the mosque\nProtecting the mosque from praying in it',
#   'image': 'prop_meme_00001.jpg'},
#  {'id': '00002',
#   'text': 'After the Arab officials betrayed their people, the time has now come to find anything to satisfy the people about the Palestinian cause',
#   'image': 'prop_meme_00002.jpg'},
#  {'id': '00003',
#   'text': 'When Bouteflika asks how long he wants Ranissa to spend in Algeria',
#   'image': 'prop_meme_00003.jpg'},
#  {'id': '00004',
#   'text': 'If I put my hands on you or look at your chest more than once by mistake, or if I open up sexual topics in front of you, it does not mean that I am harassing you. No, never. All of these are normal things between friends.',
#   'image': 'prop_meme_00004.jpg'},
#  {'id': '00005',
#   'text': '*Israel*\n*Killing, demolition, and arrests\n*Settlements\n*Annexation of the Western Bank\n*Stealing Palestinian money\nTo the Palestinian Authority\nWe will reconsider our relationship with the Israelis',
#   'image': 'prop_meme_00005.jpg'},
#  {'id': '00006',
#   'text': 'The judge has a period\nThe lawyer of the accused who broke the traffic signal is trying to convince her that the death penalty will be commuted',
#   'image': 'prop_meme_00006.jpg'},
#  {'id': '00007',
#   'text': 'A Syrian brags that his country does not have Corona *check*',
#   'image': 'prop_meme_00007.jpg'},
#  {'id': '00008',
#   'text': 'Arab citizen\nthe government\nSomething simple is his right\nMay God protect us from the homeland and the leader of the homeland',
#   'image': 'prop_meme_00008.jpg'},
#  {'id': '00009',
#   'text': 'It says here that Jesus walks in my world\n Is he a bad person to walk around in my world?',
#   'image': 'prop_meme_00009.jpg'},
#  {'id': '00010',
#   'text': 'A Chinese person is still out of quarantine',
#   'image': 'prop_meme_00010.jpg'},
#  {'id': '00011',
#   'text': '*A poor country, as it was, found some oil*\n* U.S. military*:\nWe are coming to protect you. There is a country that wants to attack you and you will be considered the sister of the country. If you do not intervene, be afraid of the United States of America.',
#   'image': 'prop_meme_00011.jpg'},
#  {'id': '00012',
#   'text': '*When the unfortunate Jordanian citizen is in the middle of laughing at the jokes of the Lebanese demonstration and then thinks that his situation is worse than the Lebanese and that if he tried to go to the street to obtain his most basic rights, all he would get is a blow from the stick of that brown police officer*',
#   'image': 'prop_meme_00012.jpg'},
#  {'id': '00013',
#   'text': '- Khalayla: But they knew that there was no Eid prayer even though the mosques were closed throughout Ramadan',
#   'image': 'prop_meme_00013.jpg'},
#  {'id': '00014',
#   'text': 'When you imagine the opportunities for success in front of you, but then you remember that you live in an Arab country',
#   'image': 'prop_meme_00014.jpg'},
#  {'id': '00015',
#   'text': 'Ashura\nSunni\natheist\nShiite',
#   'image': 'prop_meme_00015.jpg'},
#  {'id': '00016',
#   'text': 'Endowment sheikhs stand to protect the mosque\nProtecting the mosque from praying in it',
#   'image': 'prop_meme_00016.jpg'},
#  {'id': '00017',
#   'text': 'A ship of which you are the captain will not sink',
#   'image': 'prop_meme_00017.jpg'},
#  {'id': '00018',
#   'text': 'The man who got into a fistfight with Khashoggi',
#   'image': 'prop_meme_00018.jpg'},
#  {'id': '00019',
#   'text': 'He prefers to sleep until the day he has an exam\nWhen it falls, he says the corrupt educational system has wronged me',
#   'image': 'prop_meme_00019.jpg'},
#  {'id': '00020',
#   'text': 'Sisi\nThe ancient Egyptian people',
#   'image': 'prop_meme_00020.jpg'},
#  {'id': '00021',
#   'text': 'Egypt\nIsrael is busy celebrating its holidays in October 1973\nSyria',
#   'image': 'prop_meme_00021.jpg'},
#  {'id': '00022',
#   'text': '* When you are a foreign soldier and they send you to fight in Syria, and there you find them assaulting you while wearing jeans, sandals, and half sleeves *:',
#   'image': 'prop_meme_00022.jpg'},
#  {'id': '00023',
#   'text': 'When you go to invest the money you receive in establishing farms of strawberries and cucumbers in Sudan',
#   'image': 'prop_meme_00023.jpg'},
#  {'id': '00024',
#   'text': 'Suppose the number of feminists is 163,569,463\nIgnore them as I ignored the number',
#   'image': 'prop_meme_00024.jpg'},
#  {'id': '00025',
#   'text': 'Feminist when you fall in love\nI will shave my armpits for you',
#   'image': 'prop_meme_00025.jpg'},
#  {'id': '00026',
#   'text': 'The government is trying to obtain a grant from Kuwait\nThe Jordanian audience cheered for Saddam in the Kuwait match',
#   'image': 'prop_meme_00026.jpg'},
#  {'id': '00027',
#   'text': 'The most beautiful Feminist\nThe least one defends men',
#   'image': 'prop_meme_00027.jpg'},
#  {'id': '00028',
#   'text': 'The minister of education :\nFor any question you do not know the answer to, write Al-Sisi and you will get half the grade',
#   'image': 'prop_meme_00028.jpg'},
#  {'id': '00029',
#   'text': 'MBC\nPrestige series\nArabs',
#   'image': 'prop_meme_00029.jpg'},
#  {'id': '00030',
#   'text': 'When you devote your life to making memes in order to make others laugh, then one day you post a racist meme and everyone starts attacking you.\nWhen you get upset with me one day\nRemember how many days I made you happy\n Thank you, people of denial',
#   'image': 'prop_meme_00030.jpg'},
#  {'id': '00031',
#   'text': 'Facebook sheikhs after Christmas',
#   'image': 'prop_meme_00031.jpg'},
#  {'id': '00032',
#   'text': 'With this statement you will reach the utmost levels of faith',
#   'image': 'prop_meme_00032.jpg'},
#  {'id': '00033',
#   'text': "Things men don't know about women\nDishwasher instruction manual",
#   'image': 'prop_meme_00033.jpg'},
#  {'id': '00034',
#   'text': 'The struggle of the Feminist, which is a net opener\nInternet access invented by males, from a device invented by males, on a social networking site created by males, on furniture made by males, and at a cost paid by her male father to insult males.',
#   'image': 'prop_meme_00034.jpg'},
#  {'id': '00035',
#   'text': 'The woman will provoke you with her femininity and beauty\nBe careful, brother\nA woman is a deceit and true love is a homie',
#   'image': 'prop_meme_00035.jpg'},
#  {'id': '00036',
#   'text': 'Jerusalem filter on Facebook profile\nArabs\nDeal of the century',
#   'image': 'prop_meme_00036.jpg'},
#  {'id': '00037',
#   'text': 'Guys with hair like that have a 125% chance of stealing your land',
#   'image': 'prop_meme_00037.jpg'},
#  {'id': '00038',
#   'text': 'Radical solutions to financial problems\nNew tax law and price increases',
#   'image': 'prop_meme_00038.jpg'},
#  {'id': '00039',
#   'text': 'Enough fear of society\nI have my mother peeling pomegranates for me',
#   'image': 'prop_meme_00039.jpg'},
#  {'id': '00040',
#   'text': 'Stephen Hawking: There is no evidence that God exists\nThis is conclusive evidence\nMy Lord, forgive me for I have been of the wrongdoers',
#   'image': 'prop_meme_00040.jpg'},
#  {'id': '00041',
#   'text': 'Macroger\ndear\nDrake\nArabs: Cursing his religion, look what he did\nLay lay lay lay',
#   'image': 'prop_meme_00041.jpg'},
#  {'id': '00042',
#   'text': 'Girls: I will go back in time to have sex with you again\nBoys:-\nO Messenger of God, I am at your back',
#   'image': 'prop_meme_00042.jpg'},
#  {'id': '00043',
#   'text': "Don't be afraid, my friend, she is not a biologist\nThis Egyptian woman is looking for the best way to divorce her husband and steal his children and money from him",
#   'image': 'prop_meme_00043.jpg'},
#  {'id': '00044',
#   'text': "Suppose you went to the Saudi embassy\nIsn't it coming out piece by piece?",
#   'image': 'prop_meme_00044.jpg'},
#  {'id': '00045',
#   'text': 'When the girl is within 100 metres\n The closest Uber to me\nWhen the boy is within 2 kilometers\nYou will walk it, it is not worth continuing',
#   'image': 'prop_meme_00045.jpg'},
#  {'id': '00046',
#   'text': 'expensive living conditons\nHigh prices\n Poor infrastructure\nGovernment + MPs\nThe stupid citizen',
#   'image': 'prop_meme_00046.jpg'},
#  {'id': '00047',
#   'text': "She doesn't know how to cook.. nor wash.. and we suffer day and night with Indian series with 400 episodes.\nI divorced her",
#   'image': 'prop_meme_00047.jpg'},
#  {'id': '00048',
#   'text': 'Where should I put it, Chief?',
#   'image': 'prop_meme_00048.jpg'},
#  {'id': '00049',
#   'text': 'When you succeed in a subject\nYou are stuck in it!',
#   'image': 'prop_meme_00049.jpg'},
#  {'id': '00050',
#   'text': 'Yes to corruption... No to reform!!!\nYour candidate, Dr\nIssa Al-Amr',
#   'image': 'prop_meme_00050.jpg'},
#  {'id': '00052',
#   'text': 'You feel like your self is controlling you\nLamabhas',
#   'image': 'prop_meme_00052.jpg'},
#  {'id': '00053',
#   'text': 'Female activists demand the removal of the hijab under the slogan: A woman has the right to show her beauty',
#   'image': 'prop_meme_00053.jpg'},
#  {'id': '00054',
#   'text': 'Statues of Greek gods\nIdols of the Arab gods\nArabs, even in disbelief, taste disgust',
#   'image': 'prop_meme_00054.jpg'},
#  {'id': '00055',
#   'text': 'The day the Arabs united...\nThey bombed Yemen',
#   'image': 'prop_meme_00055.jpg'},
#  {'id': '00056',
#   'text': 'Made to kill\nMade to seduce\nSedition is worse than murder',
#   'image': 'prop_meme_00056.jpg'},
#  {'id': '00057',
#   'text': 'My jewel brother, you choose who you will be',
#   'image': 'prop_meme_00057.jpg'},
#  {'id': '00058',
#   'text': 'Settlers burn a house in the village of Duma, south of the city of Nablus, killing a child (one and a half years old) and seriously wounding his family.\nThe response of the Palestinian leadership\nDo you see all these?!\nThey hate you!',
#   'image': 'prop_meme_00058.jpg'},
#  {'id': '00060',
#   'text': "Teacher: It's nothing\n Israeli student: Me, me, me!\nTeacher: Well done and what else?",
#   'image': 'prop_meme_00060.jpg'},
#  {'id': '00061',
#   'text': 'Two sciences that have no importance in life:',
#   'image': 'prop_meme_00061.jpg'},
#  {'id': '00071',
#   'text': 'A wealthy and financially stable person\nCommunists',
#   'image': 'prop_meme_00071.jpg'},
#  {'id': '00073',
#   'text': 'When you pay taxes to fund the Challenger spacecraft project for NASA in order to brag to the world, but the spacecraft explodes before penetrating the troposphere, the American citizen.',
#   'image': 'prop_meme_00073.jpg'},
#  {'id': '00076',
#   'text': "Don't worry\n And increased confidence as you say\n“Topinks is better than Hohos.”\n It is impossible for it to be better, because life has proven that, by God, there is nothing sweeter than hohos",
#   'image': 'prop_meme_00076.jpg'},
#  {'id': '00077',
#   'text': 'Egyptians\nGive me a tome, teacher\n Turks and Lebanese\n It is forbidden for you to leave the country. You took our jobs and deprived us of our livelihood',
#   'image': 'prop_meme_00077.jpg'},
#  {'id': '00078',
#   'text': 'When the reformists take away the swimming pool and you are ignorant, grow up and become “a young man whose heart is attached to the swimming pool.”\n It appears in Suhail',
#   'image': 'prop_meme_00078.jpg'},
#  {'id': '00079',
#   'text': '*The Houthis celebrate Ghadir Day\nTihama drowns the people without salaries, the infrastructure collapses',
#   'image': 'prop_meme_00079.jpg'},
#  {'id': '00080',
#   'text': '*we make a male*\nMy friends are coming to play at home\n* his mom *\nThey play PlayStation right?\nThey play PlayStation right?',
#   'image': 'prop_meme_00080.jpg'},
#  {'id': '00081',
#   'text': 'My friend Al-Dhali is convincing us\nIt is his right to please us because he is his cousin who died fighting the Houthis in Hodeidah',
#   'image': 'prop_meme_00081.jpg'},
#  {'id': '00082',
#   'text': "Is it true that you, as a Yemeni pharmacist, started doing research on the Corona virus?\nI swear I'm not home, let me store",
#   'image': 'prop_meme_00082.jpg'},
#  {'id': '00083',
#   'text': 'General Electricity Corporation\nWe have cut off your electricity as a precautionary measure during rain and thunderstorms to ensure your safety.\nThe people\nZeina, by God, Zeina\nDento Laqta',
#   'image': 'prop_meme_00083.jpg'},
#  {'id': '00084',
#   'text': 'Objectives of the Yemeni revolution\nGoals without purpose',
#   'image': 'prop_meme_00084.jpg'},
#  {'id': '00085',
#   'text': '*Yemen*\nSaudi Arabia\nPlease provide first-class medical assistance\n*Yemen*\nSaudi Arabia\nDate what?\nWe need services such as electricity and water\n*Yemen*\nSaudi Arabia\nI hope you have good quality dates',
#   'image': 'prop_meme_00085.jpg'},
#  {'id': '00087',
#   'text': 'The collapse of the Yemeni riyal and food commodities are rising\ninsane\nAgain, higher again!\nEggs per size are 90 riyals',
#   'image': 'prop_meme_00087.jpg'},
#  {'id': '00088',
#   'text': 'By death:\n Ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha\nVivi\nAbdo\nScent\nHassoun',
#   'image': 'prop_meme_00088.jpg'},
#  {'id': '00089',
#   'text': 'President of France\nHe backs down from increasing fuel prices\nA tender baby',
#   'image': 'prop_meme_00089.jpg'},
#  {'id': '00090',
#   'text': "Al-Madani always comes tonight\n# Cover it with us, O Lord\nWhy aren't the workers wearing masks?\n Where is the civilian here?\nHe asks me. He asks me",
#   'image': 'prop_meme_00090.jpg'},
#  {'id': '00091',
#   'text': "When people's birthdays are in the month of one or two, there are no exams and remain in the month of 3\n*Born in month 3*\n*Born in month 1.2*\nIt's about to be D5. I've lived there for years",
#   'image': 'prop_meme_00091.jpg'},
#  {'id': '00092',
#   'text': 'We will go back to the old days. I will ring you and you will know that I have received two rings and you will know that I have arrived\nYou open up to me\nI swear to God that I will remove you from the face of the earth',
#   'image': 'prop_meme_00092.jpg'},
#  {'id': '00093',
#   'text': "your news\nMustafa Madbouly\n My fellow ministers and I do not sleep to improve citizens' lives\nJust sleep, and life will improve on its own",
#   'image': 'prop_meme_00093.jpg'},
#  {'id': '00094',
#   'text': 'The student whose temperature will increase will have a handkerchief in the committee\nMake compresses first, okay',
#   'image': 'prop_meme_00094.jpg'},
#  {'id': '00095',
#   'text': 'Before the pause and its crowding and the people busy with its meat\nThe speed of the Internet is still great, and I wanted to return to its sweetest love\nEnough messages from this friend of yours, our relationship with each other will be ruined because of it',
#   'image': 'prop_meme_00095.jpg'},
#  {'id': '00096',
#   'text': 'Are you satisfied with a woman who lets her husband go to work every morning without breakfast?\nDo you break your fast every day??',
#   'image': 'prop_meme_00096.jpg'},
#  {'id': '00097',
#   'text': 'Christians celebrate and Muslims celebrate\nWe still tax holidays',
#   'image': 'prop_meme_00097.jpg'},
#  {'id': '00099',
#   'text': 'Go away, love, go away by saying no, no, by saying...I swear to God, with the flip flops',
#   'image': 'prop_meme_00099.jpg'},
#  {'id': '00100',
#   'text': 'When he tells you that you are tired all day, be afraid to sleep and rest. Know that the second one is online.',
#   'image': 'prop_meme_00100.jpg'},
#  {'id': '00101',
#   'text': 'Who do I talk to when I want to address the Egyptian people?!\nCall anyone from Menoufia',
#   'image': 'prop_meme_00101.jpg'},
#  {'id': '00109',
#   'text': 'Show me the person who separates you from all people and makes you happy (@)?',
#   'image': 'prop_meme_00109.jpg'},
#  {'id': '00110',
#   'text': 'You hold your mobile phone a lot, by the way\nA5 m is mine',
#   'image': 'prop_meme_00110.jpg'},
#  {'id': '00111',
#   'text': 'He applies for a job and asks for a photo with a white background',
#   'image': 'prop_meme_00111.jpg'},
#  {'id': '00112',
#   'text': 'We cling to studies, knowledge, and certificates because they are the only thing that gets us out of the dirty East',
#   'image': 'prop_meme_00112.jpg'},
#  {'id': '00116',
#   'text': 'Do not respond too much to messages, as they lead to Messenger and from there to WhatsApp, God forbid.',
#   'image': 'prop_meme_00116.jpg'},
#  {'id': '00117',
#   'text': 'They said she was stubborn and strong and nothing would affect her.',
#   'image': 'prop_meme_00117.jpg'},
#  {'id': '00118',
#   'text': 'I told her: I like you..\n She said to me: Talk to me about your future. Tell her: Talk to me about your past. She said to me: God is Forgiving and Merciful. I told her: God is Provider and Generous.',
#   'image': 'prop_meme_00118.jpg'},
#  {'id': '00119',
#   'text': "What are you praying for?\nOh, it's okay, you thought I was a slave of a can of tuna, a Muslim and a believer in God",
#   'image': 'prop_meme_00119.jpg'},
#  {'id': '00120',
#   'text': 'We will achieve our dream after a while\nWe are determined if we want',
#   'image': 'prop_meme_00120.jpg'},
#  {'id': '00121',
#   'text': "I held the book for 3 minutes without turning on the phone.\nThey're coming to you, first timers",
#   'image': 'prop_meme_00121.jpg'},
#  {'id': '00125',
#   'text': 'Oh animal, oh dog, you will get rid of the internet',
#   'image': 'prop_meme_00125.jpg'},
#  {'id': '00127',
#   'text': 'The one was going to work on Sunday\n May God forgive us...',
#   'image': 'prop_meme_00127.jpg'},
#  {'id': '00128',
#   'text': "I don't remember anything, and I don't think I'm going to fall for what I'm doing to myself. This is it, please.\nSaadia Shukri Abdel Rahman 99.9, first on the Galaxy",
#   'image': 'prop_meme_00128.jpg'},
#  {'id': '00129',
#   'text': 'A foreign woman was surprised by labor while swimming in Dahab, so her father and husband gave birth to her underwater and she came out of the sea very simply.\nI hear you, who has been lying with your mother since the second month',
#   'image': 'prop_meme_00129.jpg'},
#  {'id': '00130',
#   'text': 'The mask fell from my nostrils for a while, as I was suffocating and unable to take my breath away from the person watching over us:\nThe student who pulled down the sleeve was not a, a, a, a, ah',
#   'image': 'prop_meme_00130.jpg'},
#  {'id': '00131',
#   'text': 'To my future wife...I will make you visit this section every year',
#   'image': 'prop_meme_00131.jpg'},
#  {'id': '00132',
#   'text': 'I was standing watching the apartment after removing the carpets and setting off for Eid',
#   'image': 'prop_meme_00132.jpg'},
#  {'id': '00133',
#   'text': 'Do not disturb the child before sleeping so that it does not affect his mental health\n= Me and my son before bed',
#   'image': 'prop_meme_00133.jpg'},
#  {'id': '00135',
#   'text': 'Youssef Amon\nIn principle, if Corona comes to me, I will chant in the Nile',
#   'image': 'prop_meme_00135.jpg'},
#  {'id': '00136',
#   'text': 'Every laugh has a price\nPlayStation 5 killed me',
#   'image': 'prop_meme_00136.jpg'},
#  {'id': '00137',
#   'text': "Why did you cheat like this?\n = So that I don't worry about myself like you..",
#   'image': 'prop_meme_00137.jpg'},
#  {'id': '00138',
#   'text': 'I mean, we will leave all these beautiful young men!\nWe will only marry one person!',
#   'image': 'prop_meme_00138.jpg'},
#  {'id': '00139',
#   'text': '-You will know how to use it and do the research on your own\n*Question D5, if it is repeated, I will eat and leave you alone*\n*Come work for me*',
#   'image': 'prop_meme_00139.jpg'},
#  {'id': '00140',
#   'text': 'We have women who reject a groom and say they are going with someone else\n = Who do you agree with?\nKeep walking with him',
#   'image': 'prop_meme_00140.jpg'},
#  {'id': '00145',
#   'text': 'Scientists: The image cannot be heard\nImage',
#   'image': 'prop_meme_00145.jpg'},
#  {'id': '00146',
#   'text': '-Is this the Minister of Education?\n*Yes\n -I want my money for myself and I am not raised or worked',
#   'image': 'prop_meme_00146.jpg'},
#  {'id': '00147',
#   'text': 'I am ready\nSay goodbye to drowning with the Five-Piece Float Kit',
#   'image': 'prop_meme_00147.jpg'},
#  {'id': '00148',
#   'text': 'People get tired and people take the shot',
#   'image': 'prop_meme_00148.jpg'},
#  {'id': '00149',
#   'text': "People test me when I wear manicure lipstick, I don't expect it to fall, and I also look like a monster..",
#   'image': 'prop_meme_00149.jpg'},
#  {'id': '00150',
#   'text': "3 failed projects in my life:\n Diet\n I sleep before 12 o'clock\n I have a lot of money",
#   'image': 'prop_meme_00150.jpg'},
#  {'id': '00151',
#   'text': 'When we keep fighting and I am the one who is wrong and I have no excuse for what I did\nWe are envied',
#   'image': 'prop_meme_00151.jpg'},
#  {'id': '00152',
#   'text': 'We had guests and my mother was not at home and my father told me to come in and do something for us.\n*When I enter the kitchen*',
#   'image': 'prop_meme_00152.jpg'},
#  {'id': '00153',
#   'text': 'The people who made this movement when they were young, like so we can take stock of the group, are trivial',
#   'image': 'prop_meme_00153.jpg'},
#  {'id': '00159',
#   'text': 'Someone has a new suitor and is going to sit with his fiancée for a while\nHis fiancée:\nMy phone was broken',
#   'image': 'prop_meme_00159.jpg'},
#  {'id': '00168',
#   'text': 'Menoufy does not know that the pound is coming when the soul rises',
#   'image': 'prop_meme_00168.jpg'},
#  {'id': '00170',
#   'text': 'Kuteen 2020 Egyptians are not our partners, they are the nation, and they are here to serve us\nMy uncle Mubarak, join me, my uncle Mubarak',
#   'image': 'prop_meme_00170.jpg'},
#  {'id': '00175',
#   'text': 'All the streets hung Ramadan decorations\nOur street:',
#   'image': 'prop_meme_00175.jpg'},
#  {'id': '00183',
#   'text': 'Imagine how difficult life is when you are dumber than a dove',
#   'image': 'prop_meme_00183.jpg'},
#  {'id': '00200',
#   'text': '90% of students attend online lectures *Students*',
#   'image': 'prop_meme_00200.jpg'},
#  {'id': '00222',
#   'text': 'A person to whom God did not give any talent',
#   'image': 'prop_meme_00222.jpg'},
#  {'id': '00244',
#   'text': 'Stay away from the man, you hook of men',
#   'image': 'prop_meme_00244.jpg'},
#  {'id': '00275',
#   'text': 'France recorded new infections with the Corona virus, including two cases who returned from Egypt\nEgyptian Ministry of Health: My God, expose yourself!',
#   'image': 'prop_meme_00275.jpg'},
#  {'id': '00277',
#   'text': "Whoever sold us lost our pampering\nNo, I don't allow you to say that, because you were a grumpy girl, Kalb",
#   'image': 'prop_meme_00277.jpg'},
#  {'id': '00318',
#   'text': 'An Egyptian doctor heals her patients by hugging her\nNo, we will go for treatment',
#   'image': 'prop_meme_00318.jpg'},
#  {'id': '00321',
#   'text': 'Do you know how to translate the movie, Bassiouni?\nLook, Pasha, I will surprise you\nOh, the one who is on the canal, Houd Al-Maleh!',
#   'image': 'prop_meme_00321.jpg'},
#  {'id': '00322',
#   'text': "I really want to be in a relationship with someone like you\nI'm like myself",
#   'image': 'prop_meme_00322.jpg'},
#  {'id': '00323',
#   'text': "I don't know why I should open it to you at all\nI don't know what is the secret of my love for you and for opening you every little while, Madam, there is no way to let me through",
#   'image': 'prop_meme_00323.jpg'},
#  {'id': '00324',
#   'text': "My brother and I didn't make a light dinner at night after everyone in the house went to sleep",
#   'image': 'prop_meme_00324.jpg'},
#  {'id': '00325',
#   'text': 'No, there is no permissibility now, our daughter is still stupid\n=...',
#   'image': 'prop_meme_00325.jpg'},
#  {'id': '00326',
#   'text': "I'm going to swim to these barrels\nWe don't have an invitation",
#   'image': 'prop_meme_00326.jpg'},
#  {'id': '00327',
#   'text': 'I thought that there was a dirty demon controlling us all year long\n\nThe person turned out to be dirty and oppressive, the devil was with him',
#   'image': 'prop_meme_00327.jpg'},
#  {'id': '00354',
#   'text': 'May God have mercy on you, grandfather.. You were a thief and also a liar\nChina is sweet',
#   'image': 'prop_meme_00354.jpg'},
#  {'id': '00368',
#   'text': 'Soso, my friend, told me about your faults that I did not see in you: you are a traitor, you are a cheat, you are a contemptible person, you are a monster.\n*her friend*\nI love you',
#   'image': 'prop_meme_00368.jpg'},
#  {'id': '00369',
#   'text': "The second semester will be canceled if violence breaks out\nSo it's war",
#   'image': 'prop_meme_00369.jpg'},
#  {'id': '00373',
#   'text': "When I wear Eid clothes and I don't know where to go with them",
#   'image': 'prop_meme_00373.jpg'},
#  {'id': '00374',
#   'text': 'Who is calling you to eat something else? I have eaten\nMy son, everyone',
#   'image': 'prop_meme_00374.jpg'},
#  {'id': '00375',
#   'text': 'Ready, kids?\nHey hey captain\nAnd the Prophet compensates Ali',
#   'image': 'prop_meme_00375.jpg'},
#  {'id': '00376',
#   'text': 'My daughter, all this sleep, get up and sit with us for a while!!\nI\nWhy do I take a nap for two days like this?',
#   'image': 'prop_meme_00376.jpg'},
#  {'id': '00399',
#   'text': 'If the wife knows that her husband’s salary has been reduced',
#   'image': 'prop_meme_00399.jpg'},
#  {'id': '00426',
#   'text': 'When you fear for the batch group\nBatch Jews:\nI finished the research, guys, very easy',
#   'image': 'prop_meme_00426.jpg'},
#  {'id': '00428',
#   'text': "China announces the death of the first case of Hantavirus\n\nWhat can I tell you, don't give it nuclear power and save us",
#   'image': 'prop_meme_00428.jpg'},
#  {'id': '00431',
#   'text': "*You*\nYou don't remember him anymore, loser\n Please don't call me a loser\nAre you upset with me, loser?\nOkay, you loser, you loser, you loser",
#   'image': 'prop_meme_00431.jpg'},
#  {'id': '00447',
#   'text': 'I was busy in my dream about you all last night\nhow did you see me ?\nUneducated',
#   'image': 'prop_meme_00447.jpg'},
#  {'id': '00460',
#   'text': 'Marriage, my brothers, is a failed project\n\nGot Engaged Today\n\nMy resemblance will remain, and your resemblance will be my life and your age',
#   'image': 'prop_meme_00460.jpg'},
#  {'id': '00472',
#   'text': 'North Korea announces its discovery of a cure for AIDS and Ebola',
#   'image': 'prop_meme_00472.jpg'},
#  {'id': '00479',
#   'text': '*your friend*\nYou are the one who told me that we must work hard to succeed and come out on top\n\n*You*\nYou talk to the teachers so we can start lessons, you idiot',
#   'image': 'prop_meme_00479.jpg'},
#  {'id': '00482',
#   'text': "When I'm sitting with people and I hear someone talking wrongly, I know what's right.\nIt is not my business\nIt is not my business\n It is not my business\nIt is not my business\n It is not my business\nIt is not my business\n It is not my business",
#   'image': 'prop_meme_00482.jpg'},
#  {'id': '00483',
#   'text': 'Everyone got engaged and got engaged in 2017\nExcept me and you, oh jinx, oh jinx',
#   'image': 'prop_meme_00483.jpg'},
#  {'id': '00490',
#   'text': 'You must forgive those who wronged you because we are in open days\nRespectful words and everything, but may God protect them',
#   'image': 'prop_meme_00490.jpg'},
#  {'id': '00491',
#   'text': 'China is fully recovering from Corona and warns its people against traveling to affected countries.',
#   'image': 'prop_meme_00491.jpg'},
#  {'id': '00499',
#   'text': "This cat's life is very miserable and he is poor and does not have a quarter of a tuna💔",
#   'image': 'prop_meme_00499.jpg'},
#  {'id': '00506',
#   'text': '| Is this Corona virus or not?\n I swear to God, my daughter, as long as you are sad about the whole world, then for sure women will be too😂😂',
#   'image': 'prop_meme_00506.jpg'},
#  {'id': '00541',
#   'text': 'Would you beat up your best friends for a million dollars??\nI:',
#   'image': 'prop_meme_00541.jpg'},
#  {'id': '00542',
#   'text': 'My children after you bullied half the planet',
#   'image': 'prop_meme_00542.jpg'},
#  {'id': '00573',
#   'text': 'When you come home late and your father tells you where you are now, dog:',
#   'image': 'prop_meme_00573.jpg'}]

# %%
"""
for utterance in trial_data:
  d = trained_nlp(utterance["text"]).cats
  label = max(d, key =d.get)
  utterance["label"] = label
"""
# Out:
# '\nfor utterance in trial_data:\n  d = trained_nlp(utterance["text"]).cats\n  label = max(d, key =d.get)\n  utterance["label"] = label\n'

# %%
#CANGED
for utterance in trial_data:
  try:
    texty = utterance["text"].replace("\\n", " ").lower()    #removing new-line-characters(\\n) and lowering the text
  except:
    texty = utterance["text"].lower()
  d = trained_nlp(texty).cats
  label = max(d, key =d.get)
  utterance["label"] = label

# %%
trial_data
# Out:
# [{'id': '00001',
#   'text': 'Endowment sheikhs stand to protect the mosque\nProtecting the mosque from praying in it',
#   'image': 'prop_meme_00001.jpg',
#   'label': 'propagandistic'},
#  {'id': '00002',
#   'text': 'After the Arab officials betrayed their people, the time has now come to find anything to satisfy the people about the Palestinian cause',
#   'image': 'prop_meme_00002.jpg',
#   'label': 'propagandistic'},
#  {'id': '00003',
#   'text': 'When Bouteflika asks how long he wants Ranissa to spend in Algeria',
#   'image': 'prop_meme_00003.jpg',
#   'label': 'propagandistic'},
#  {'id': '00004',
#   'text': 'If I put my hands on you or look at your chest more than once by mistake, or if I open up sexual topics in front of you, it does not mean that I am harassing you. No, never. All of these are normal things between friends.',
#   'image': 'prop_meme_00004.jpg',
#   'label': 'propagandistic'},
#  {'id': '00005',
#   'text': '*Israel*\n*Killing, demolition, and arrests\n*Settlements\n*Annexation of the Western Bank\n*Stealing Palestinian money\nTo the Palestinian Authority\nWe will reconsider our relationship with the Israelis',
#   'image': 'prop_meme_00005.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00006',
#   'text': 'The judge has a period\nThe lawyer of the accused who broke the traffic signal is trying to convince her that the death penalty will be commuted',
#   'image': 'prop_meme_00006.jpg',
#   'label': 'propagandistic'},
#  {'id': '00007',
#   'text': 'A Syrian brags that his country does not have Corona *check*',
#   'image': 'prop_meme_00007.jpg',
#   'label': 'propagandistic'},
#  {'id': '00008',
#   'text': 'Arab citizen\nthe government\nSomething simple is his right\nMay God protect us from the homeland and the leader of the homeland',
#   'image': 'prop_meme_00008.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00009',
#   'text': 'It says here that Jesus walks in my world\n Is he a bad person to walk around in my world?',
#   'image': 'prop_meme_00009.jpg',
#   'label': 'propagandistic'},
#  {'id': '00010',
#   'text': 'A Chinese person is still out of quarantine',
#   'image': 'prop_meme_00010.jpg',
#   'label': 'propagandistic'},
#  {'id': '00011',
#   'text': '*A poor country, as it was, found some oil*\n* U.S. military*:\nWe are coming to protect you. There is a country that wants to attack you and you will be considered the sister of the country. If you do not intervene, be afraid of the United States of America.',
#   'image': 'prop_meme_00011.jpg',
#   'label': 'propagandistic'},
#  {'id': '00012',
#   'text': '*When the unfortunate Jordanian citizen is in the middle of laughing at the jokes of the Lebanese demonstration and then thinks that his situation is worse than the Lebanese and that if he tried to go to the street to obtain his most basic rights, all he would get is a blow from the stick of that brown police officer*',
#   'image': 'prop_meme_00012.jpg',
#   'label': 'propagandistic'},
#  {'id': '00013',
#   'text': '- Khalayla: But they knew that there was no Eid prayer even though the mosques were closed throughout Ramadan',
#   'image': 'prop_meme_00013.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00014',
#   'text': 'When you imagine the opportunities for success in front of you, but then you remember that you live in an Arab country',
#   'image': 'prop_meme_00014.jpg',
#   'label': 'propagandistic'},
#  {'id': '00015',
#   'text': 'Ashura\nSunni\natheist\nShiite',
#   'image': 'prop_meme_00015.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00016',
#   'text': 'Endowment sheikhs stand to protect the mosque\nProtecting the mosque from praying in it',
#   'image': 'prop_meme_00016.jpg',
#   'label': 'propagandistic'},
#  {'id': '00017',
#   'text': 'A ship of which you are the captain will not sink',
#   'image': 'prop_meme_00017.jpg',
#   'label': 'propagandistic'},
#  {'id': '00018',
#   'text': 'The man who got into a fistfight with Khashoggi',
#   'image': 'prop_meme_00018.jpg',
#   'label': 'propagandistic'},
#  {'id': '00019',
#   'text': 'He prefers to sleep until the day he has an exam\nWhen it falls, he says the corrupt educational system has wronged me',
#   'image': 'prop_meme_00019.jpg',
#   'label': 'propagandistic'},
#  {'id': '00020',
#   'text': 'Sisi\nThe ancient Egyptian people',
#   'image': 'prop_meme_00020.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00021',
#   'text': 'Egypt\nIsrael is busy celebrating its holidays in October 1973\nSyria',
#   'image': 'prop_meme_00021.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00022',
#   'text': '* When you are a foreign soldier and they send you to fight in Syria, and there you find them assaulting you while wearing jeans, sandals, and half sleeves *:',
#   'image': 'prop_meme_00022.jpg',
#   'label': 'propagandistic'},
#  {'id': '00023',
#   'text': 'When you go to invest the money you receive in establishing farms of strawberries and cucumbers in Sudan',
#   'image': 'prop_meme_00023.jpg',
#   'label': 'propagandistic'},
#  {'id': '00024',
#   'text': 'Suppose the number of feminists is 163,569,463\nIgnore them as I ignored the number',
#   'image': 'prop_meme_00024.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00025',
#   'text': 'Feminist when you fall in love\nI will shave my armpits for you',
#   'image': 'prop_meme_00025.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00026',
#   'text': 'The government is trying to obtain a grant from Kuwait\nThe Jordanian audience cheered for Saddam in the Kuwait match',
#   'image': 'prop_meme_00026.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00027',
#   'text': 'The most beautiful Feminist\nThe least one defends men',
#   'image': 'prop_meme_00027.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00028',
#   'text': 'The minister of education :\nFor any question you do not know the answer to, write Al-Sisi and you will get half the grade',
#   'image': 'prop_meme_00028.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00029',
#   'text': 'MBC\nPrestige series\nArabs',
#   'image': 'prop_meme_00029.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00030',
#   'text': 'When you devote your life to making memes in order to make others laugh, then one day you post a racist meme and everyone starts attacking you.\nWhen you get upset with me one day\nRemember how many days I made you happy\n Thank you, people of denial',
#   'image': 'prop_meme_00030.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00031',
#   'text': 'Facebook sheikhs after Christmas',
#   'image': 'prop_meme_00031.jpg',
#   'label': 'propagandistic'},
#  {'id': '00032',
#   'text': 'With this statement you will reach the utmost levels of faith',
#   'image': 'prop_meme_00032.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00033',
#   'text': "Things men don't know about women\nDishwasher instruction manual",
#   'image': 'prop_meme_00033.jpg',
#   'label': 'propagandistic'},
#  {'id': '00034',
#   'text': 'The struggle of the Feminist, which is a net opener\nInternet access invented by males, from a device invented by males, on a social networking site created by males, on furniture made by males, and at a cost paid by her male father to insult males.',
#   'image': 'prop_meme_00034.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00035',
#   'text': 'The woman will provoke you with her femininity and beauty\nBe careful, brother\nA woman is a deceit and true love is a homie',
#   'image': 'prop_meme_00035.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00036',
#   'text': 'Jerusalem filter on Facebook profile\nArabs\nDeal of the century',
#   'image': 'prop_meme_00036.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00037',
#   'text': 'Guys with hair like that have a 125% chance of stealing your land',
#   'image': 'prop_meme_00037.jpg',
#   'label': 'propagandistic'},
#  {'id': '00038',
#   'text': 'Radical solutions to financial problems\nNew tax law and price increases',
#   'image': 'prop_meme_00038.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00039',
#   'text': 'Enough fear of society\nI have my mother peeling pomegranates for me',
#   'image': 'prop_meme_00039.jpg',
#   'label': 'propagandistic'},
#  {'id': '00040',
#   'text': 'Stephen Hawking: There is no evidence that God exists\nThis is conclusive evidence\nMy Lord, forgive me for I have been of the wrongdoers',
#   'image': 'prop_meme_00040.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00041',
#   'text': 'Macroger\ndear\nDrake\nArabs: Cursing his religion, look what he did\nLay lay lay lay',
#   'image': 'prop_meme_00041.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00042',
#   'text': 'Girls: I will go back in time to have sex with you again\nBoys:-\nO Messenger of God, I am at your back',
#   'image': 'prop_meme_00042.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00043',
#   'text': "Don't be afraid, my friend, she is not a biologist\nThis Egyptian woman is looking for the best way to divorce her husband and steal his children and money from him",
#   'image': 'prop_meme_00043.jpg',
#   'label': 'propagandistic'},
#  {'id': '00044',
#   'text': "Suppose you went to the Saudi embassy\nIsn't it coming out piece by piece?",
#   'image': 'prop_meme_00044.jpg',
#   'label': 'propagandistic'},
#  {'id': '00045',
#   'text': 'When the girl is within 100 metres\n The closest Uber to me\nWhen the boy is within 2 kilometers\nYou will walk it, it is not worth continuing',
#   'image': 'prop_meme_00045.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00046',
#   'text': 'expensive living conditons\nHigh prices\n Poor infrastructure\nGovernment + MPs\nThe stupid citizen',
#   'image': 'prop_meme_00046.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00047',
#   'text': "She doesn't know how to cook.. nor wash.. and we suffer day and night with Indian series with 400 episodes.\nI divorced her",
#   'image': 'prop_meme_00047.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00048',
#   'text': 'Where should I put it, Chief?',
#   'image': 'prop_meme_00048.jpg',
#   'label': 'propagandistic'},
#  {'id': '00049',
#   'text': 'When you succeed in a subject\nYou are stuck in it!',
#   'image': 'prop_meme_00049.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00050',
#   'text': 'Yes to corruption... No to reform!!!\nYour candidate, Dr\nIssa Al-Amr',
#   'image': 'prop_meme_00050.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00052',
#   'text': 'You feel like your self is controlling you\nLamabhas',
#   'image': 'prop_meme_00052.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00053',
#   'text': 'Female activists demand the removal of the hijab under the slogan: A woman has the right to show her beauty',
#   'image': 'prop_meme_00053.jpg',
#   'label': 'propagandistic'},
#  {'id': '00054',
#   'text': 'Statues of Greek gods\nIdols of the Arab gods\nArabs, even in disbelief, taste disgust',
#   'image': 'prop_meme_00054.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00055',
#   'text': 'The day the Arabs united...\nThey bombed Yemen',
#   'image': 'prop_meme_00055.jpg',
#   'label': 'propagandistic'},
#  {'id': '00056',
#   'text': 'Made to kill\nMade to seduce\nSedition is worse than murder',
#   'image': 'prop_meme_00056.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00057',
#   'text': 'My jewel brother, you choose who you will be',
#   'image': 'prop_meme_00057.jpg',
#   'label': 'propagandistic'},
#  {'id': '00058',
#   'text': 'Settlers burn a house in the village of Duma, south of the city of Nablus, killing a child (one and a half years old) and seriously wounding his family.\nThe response of the Palestinian leadership\nDo you see all these?!\nThey hate you!',
#   'image': 'prop_meme_00058.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00060',
#   'text': "Teacher: It's nothing\n Israeli student: Me, me, me!\nTeacher: Well done and what else?",
#   'image': 'prop_meme_00060.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00061',
#   'text': 'Two sciences that have no importance in life:',
#   'image': 'prop_meme_00061.jpg',
#   'label': 'propagandistic'},
#  {'id': '00071',
#   'text': 'A wealthy and financially stable person\nCommunists',
#   'image': 'prop_meme_00071.jpg',
#   'label': 'propagandistic'},
#  {'id': '00073',
#   'text': 'When you pay taxes to fund the Challenger spacecraft project for NASA in order to brag to the world, but the spacecraft explodes before penetrating the troposphere, the American citizen.',
#   'image': 'prop_meme_00073.jpg',
#   'label': 'propagandistic'},
#  {'id': '00076',
#   'text': "Don't worry\n And increased confidence as you say\n“Topinks is better than Hohos.”\n It is impossible for it to be better, because life has proven that, by God, there is nothing sweeter than hohos",
#   'image': 'prop_meme_00076.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00077',
#   'text': 'Egyptians\nGive me a tome, teacher\n Turks and Lebanese\n It is forbidden for you to leave the country. You took our jobs and deprived us of our livelihood',
#   'image': 'prop_meme_00077.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00078',
#   'text': 'When the reformists take away the swimming pool and you are ignorant, grow up and become “a young man whose heart is attached to the swimming pool.”\n It appears in Suhail',
#   'image': 'prop_meme_00078.jpg',
#   'label': 'propagandistic'},
#  {'id': '00079',
#   'text': '*The Houthis celebrate Ghadir Day\nTihama drowns the people without salaries, the infrastructure collapses',
#   'image': 'prop_meme_00079.jpg',
#   'label': 'propagandistic'},
#  {'id': '00080',
#   'text': '*we make a male*\nMy friends are coming to play at home\n* his mom *\nThey play PlayStation right?\nThey play PlayStation right?',
#   'image': 'prop_meme_00080.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00081',
#   'text': 'My friend Al-Dhali is convincing us\nIt is his right to please us because he is his cousin who died fighting the Houthis in Hodeidah',
#   'image': 'prop_meme_00081.jpg',
#   'label': 'propagandistic'},
#  {'id': '00082',
#   'text': "Is it true that you, as a Yemeni pharmacist, started doing research on the Corona virus?\nI swear I'm not home, let me store",
#   'image': 'prop_meme_00082.jpg',
#   'label': 'propagandistic'},
#  {'id': '00083',
#   'text': 'General Electricity Corporation\nWe have cut off your electricity as a precautionary measure during rain and thunderstorms to ensure your safety.\nThe people\nZeina, by God, Zeina\nDento Laqta',
#   'image': 'prop_meme_00083.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00084',
#   'text': 'Objectives of the Yemeni revolution\nGoals without purpose',
#   'image': 'prop_meme_00084.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00085',
#   'text': '*Yemen*\nSaudi Arabia\nPlease provide first-class medical assistance\n*Yemen*\nSaudi Arabia\nDate what?\nWe need services such as electricity and water\n*Yemen*\nSaudi Arabia\nI hope you have good quality dates',
#   'image': 'prop_meme_00085.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00087',
#   'text': 'The collapse of the Yemeni riyal and food commodities are rising\ninsane\nAgain, higher again!\nEggs per size are 90 riyals',
#   'image': 'prop_meme_00087.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00088',
#   'text': 'By death:\n Ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha-ha\nVivi\nAbdo\nScent\nHassoun',
#   'image': 'prop_meme_00088.jpg',
#   'label': 'propagandistic'},
#  {'id': '00089',
#   'text': 'President of France\nHe backs down from increasing fuel prices\nA tender baby',
#   'image': 'prop_meme_00089.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00090',
#   'text': "Al-Madani always comes tonight\n# Cover it with us, O Lord\nWhy aren't the workers wearing masks?\n Where is the civilian here?\nHe asks me. He asks me",
#   'image': 'prop_meme_00090.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00091',
#   'text': "When people's birthdays are in the month of one or two, there are no exams and remain in the month of 3\n*Born in month 3*\n*Born in month 1.2*\nIt's about to be D5. I've lived there for years",
#   'image': 'prop_meme_00091.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00092',
#   'text': 'We will go back to the old days. I will ring you and you will know that I have received two rings and you will know that I have arrived\nYou open up to me\nI swear to God that I will remove you from the face of the earth',
#   'image': 'prop_meme_00092.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00093',
#   'text': "your news\nMustafa Madbouly\n My fellow ministers and I do not sleep to improve citizens' lives\nJust sleep, and life will improve on its own",
#   'image': 'prop_meme_00093.jpg',
#   'label': 'propagandistic'},
#  {'id': '00094',
#   'text': 'The student whose temperature will increase will have a handkerchief in the committee\nMake compresses first, okay',
#   'image': 'prop_meme_00094.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00095',
#   'text': 'Before the pause and its crowding and the people busy with its meat\nThe speed of the Internet is still great, and I wanted to return to its sweetest love\nEnough messages from this friend of yours, our relationship with each other will be ruined because of it',
#   'image': 'prop_meme_00095.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00096',
#   'text': 'Are you satisfied with a woman who lets her husband go to work every morning without breakfast?\nDo you break your fast every day??',
#   'image': 'prop_meme_00096.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00097',
#   'text': 'Christians celebrate and Muslims celebrate\nWe still tax holidays',
#   'image': 'prop_meme_00097.jpg',
#   'label': 'propagandistic'},
#  {'id': '00099',
#   'text': 'Go away, love, go away by saying no, no, by saying...I swear to God, with the flip flops',
#   'image': 'prop_meme_00099.jpg',
#   'label': 'propagandistic'},
#  {'id': '00100',
#   'text': 'When he tells you that you are tired all day, be afraid to sleep and rest. Know that the second one is online.',
#   'image': 'prop_meme_00100.jpg',
#   'label': 'propagandistic'},
#  {'id': '00101',
#   'text': 'Who do I talk to when I want to address the Egyptian people?!\nCall anyone from Menoufia',
#   'image': 'prop_meme_00101.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00109',
#   'text': 'Show me the person who separates you from all people and makes you happy (@)?',
#   'image': 'prop_meme_00109.jpg',
#   'label': 'propagandistic'},
#  {'id': '00110',
#   'text': 'You hold your mobile phone a lot, by the way\nA5 m is mine',
#   'image': 'prop_meme_00110.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00111',
#   'text': 'He applies for a job and asks for a photo with a white background',
#   'image': 'prop_meme_00111.jpg',
#   'label': 'propagandistic'},
#  {'id': '00112',
#   'text': 'We cling to studies, knowledge, and certificates because they are the only thing that gets us out of the dirty East',
#   'image': 'prop_meme_00112.jpg',
#   'label': 'propagandistic'},
#  {'id': '00116',
#   'text': 'Do not respond too much to messages, as they lead to Messenger and from there to WhatsApp, God forbid.',
#   'image': 'prop_meme_00116.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00117',
#   'text': 'They said she was stubborn and strong and nothing would affect her.',
#   'image': 'prop_meme_00117.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00118',
#   'text': 'I told her: I like you..\n She said to me: Talk to me about your future. Tell her: Talk to me about your past. She said to me: God is Forgiving and Merciful. I told her: God is Provider and Generous.',
#   'image': 'prop_meme_00118.jpg',
#   'label': 'propagandistic'},
#  {'id': '00119',
#   'text': "What are you praying for?\nOh, it's okay, you thought I was a slave of a can of tuna, a Muslim and a believer in God",
#   'image': 'prop_meme_00119.jpg',
#   'label': 'propagandistic'},
#  {'id': '00120',
#   'text': 'We will achieve our dream after a while\nWe are determined if we want',
#   'image': 'prop_meme_00120.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00121',
#   'text': "I held the book for 3 minutes without turning on the phone.\nThey're coming to you, first timers",
#   'image': 'prop_meme_00121.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00125',
#   'text': 'Oh animal, oh dog, you will get rid of the internet',
#   'image': 'prop_meme_00125.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00127',
#   'text': 'The one was going to work on Sunday\n May God forgive us...',
#   'image': 'prop_meme_00127.jpg',
#   'label': 'propagandistic'},
#  {'id': '00128',
#   'text': "I don't remember anything, and I don't think I'm going to fall for what I'm doing to myself. This is it, please.\nSaadia Shukri Abdel Rahman 99.9, first on the Galaxy",
#   'image': 'prop_meme_00128.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00129',
#   'text': 'A foreign woman was surprised by labor while swimming in Dahab, so her father and husband gave birth to her underwater and she came out of the sea very simply.\nI hear you, who has been lying with your mother since the second month',
#   'image': 'prop_meme_00129.jpg',
#   'label': 'propagandistic'},
#  {'id': '00130',
#   'text': 'The mask fell from my nostrils for a while, as I was suffocating and unable to take my breath away from the person watching over us:\nThe student who pulled down the sleeve was not a, a, a, a, ah',
#   'image': 'prop_meme_00130.jpg',
#   'label': 'propagandistic'},
#  {'id': '00131',
#   'text': 'To my future wife...I will make you visit this section every year',
#   'image': 'prop_meme_00131.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00132',
#   'text': 'I was standing watching the apartment after removing the carpets and setting off for Eid',
#   'image': 'prop_meme_00132.jpg',
#   'label': 'propagandistic'},
#  {'id': '00133',
#   'text': 'Do not disturb the child before sleeping so that it does not affect his mental health\n= Me and my son before bed',
#   'image': 'prop_meme_00133.jpg',
#   'label': 'propagandistic'},
#  {'id': '00135',
#   'text': 'Youssef Amon\nIn principle, if Corona comes to me, I will chant in the Nile',
#   'image': 'prop_meme_00135.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00136',
#   'text': 'Every laugh has a price\nPlayStation 5 killed me',
#   'image': 'prop_meme_00136.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00137',
#   'text': "Why did you cheat like this?\n = So that I don't worry about myself like you..",
#   'image': 'prop_meme_00137.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00138',
#   'text': 'I mean, we will leave all these beautiful young men!\nWe will only marry one person!',
#   'image': 'prop_meme_00138.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00139',
#   'text': '-You will know how to use it and do the research on your own\n*Question D5, if it is repeated, I will eat and leave you alone*\n*Come work for me*',
#   'image': 'prop_meme_00139.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00140',
#   'text': 'We have women who reject a groom and say they are going with someone else\n = Who do you agree with?\nKeep walking with him',
#   'image': 'prop_meme_00140.jpg',
#   'label': 'propagandistic'},
#  {'id': '00145',
#   'text': 'Scientists: The image cannot be heard\nImage',
#   'image': 'prop_meme_00145.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00146',
#   'text': '-Is this the Minister of Education?\n*Yes\n -I want my money for myself and I am not raised or worked',
#   'image': 'prop_meme_00146.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00147',
#   'text': 'I am ready\nSay goodbye to drowning with the Five-Piece Float Kit',
#   'image': 'prop_meme_00147.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00148',
#   'text': 'People get tired and people take the shot',
#   'image': 'prop_meme_00148.jpg',
#   'label': 'propagandistic'},
#  {'id': '00149',
#   'text': "People test me when I wear manicure lipstick, I don't expect it to fall, and I also look like a monster..",
#   'image': 'prop_meme_00149.jpg',
#   'label': 'propagandistic'},
#  {'id': '00150',
#   'text': "3 failed projects in my life:\n Diet\n I sleep before 12 o'clock\n I have a lot of money",
#   'image': 'prop_meme_00150.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00151',
#   'text': 'When we keep fighting and I am the one who is wrong and I have no excuse for what I did\nWe are envied',
#   'image': 'prop_meme_00151.jpg',
#   'label': 'propagandistic'},
#  {'id': '00152',
#   'text': 'We had guests and my mother was not at home and my father told me to come in and do something for us.\n*When I enter the kitchen*',
#   'image': 'prop_meme_00152.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00153',
#   'text': 'The people who made this movement when they were young, like so we can take stock of the group, are trivial',
#   'image': 'prop_meme_00153.jpg',
#   'label': 'propagandistic'},
#  {'id': '00159',
#   'text': 'Someone has a new suitor and is going to sit with his fiancée for a while\nHis fiancée:\nMy phone was broken',
#   'image': 'prop_meme_00159.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00168',
#   'text': 'Menoufy does not know that the pound is coming when the soul rises',
#   'image': 'prop_meme_00168.jpg',
#   'label': 'propagandistic'},
#  {'id': '00170',
#   'text': 'Kuteen 2020 Egyptians are not our partners, they are the nation, and they are here to serve us\nMy uncle Mubarak, join me, my uncle Mubarak',
#   'image': 'prop_meme_00170.jpg',
#   'label': 'propagandistic'},
#  {'id': '00175',
#   'text': 'All the streets hung Ramadan decorations\nOur street:',
#   'image': 'prop_meme_00175.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00183',
#   'text': 'Imagine how difficult life is when you are dumber than a dove',
#   'image': 'prop_meme_00183.jpg',
#   'label': 'propagandistic'},
#  {'id': '00200',
#   'text': '90% of students attend online lectures *Students*',
#   'image': 'prop_meme_00200.jpg',
#   'label': 'propagandistic'},
#  {'id': '00222',
#   'text': 'A person to whom God did not give any talent',
#   'image': 'prop_meme_00222.jpg',
#   'label': 'propagandistic'},
#  {'id': '00244',
#   'text': 'Stay away from the man, you hook of men',
#   'image': 'prop_meme_00244.jpg',
#   'label': 'propagandistic'},
#  {'id': '00275',
#   'text': 'France recorded new infections with the Corona virus, including two cases who returned from Egypt\nEgyptian Ministry of Health: My God, expose yourself!',
#   'image': 'prop_meme_00275.jpg',
#   'label': 'propagandistic'},
#  {'id': '00277',
#   'text': "Whoever sold us lost our pampering\nNo, I don't allow you to say that, because you were a grumpy girl, Kalb",
#   'image': 'prop_meme_00277.jpg',
#   'label': 'propagandistic'},
#  {'id': '00318',
#   'text': 'An Egyptian doctor heals her patients by hugging her\nNo, we will go for treatment',
#   'image': 'prop_meme_00318.jpg',
#   'label': 'propagandistic'},
#  {'id': '00321',
#   'text': 'Do you know how to translate the movie, Bassiouni?\nLook, Pasha, I will surprise you\nOh, the one who is on the canal, Houd Al-Maleh!',
#   'image': 'prop_meme_00321.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00322',
#   'text': "I really want to be in a relationship with someone like you\nI'm like myself",
#   'image': 'prop_meme_00322.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00323',
#   'text': "I don't know why I should open it to you at all\nI don't know what is the secret of my love for you and for opening you every little while, Madam, there is no way to let me through",
#   'image': 'prop_meme_00323.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00324',
#   'text': "My brother and I didn't make a light dinner at night after everyone in the house went to sleep",
#   'image': 'prop_meme_00324.jpg',
#   'label': 'propagandistic'},
#  {'id': '00325',
#   'text': 'No, there is no permissibility now, our daughter is still stupid\n=...',
#   'image': 'prop_meme_00325.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00326',
#   'text': "I'm going to swim to these barrels\nWe don't have an invitation",
#   'image': 'prop_meme_00326.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00327',
#   'text': 'I thought that there was a dirty demon controlling us all year long\n\nThe person turned out to be dirty and oppressive, the devil was with him',
#   'image': 'prop_meme_00327.jpg',
#   'label': 'propagandistic'},
#  {'id': '00354',
#   'text': 'May God have mercy on you, grandfather.. You were a thief and also a liar\nChina is sweet',
#   'image': 'prop_meme_00354.jpg',
#   'label': 'propagandistic'},
#  {'id': '00368',
#   'text': 'Soso, my friend, told me about your faults that I did not see in you: you are a traitor, you are a cheat, you are a contemptible person, you are a monster.\n*her friend*\nI love you',
#   'image': 'prop_meme_00368.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00369',
#   'text': "The second semester will be canceled if violence breaks out\nSo it's war",
#   'image': 'prop_meme_00369.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00373',
#   'text': "When I wear Eid clothes and I don't know where to go with them",
#   'image': 'prop_meme_00373.jpg',
#   'label': 'propagandistic'},
#  {'id': '00374',
#   'text': 'Who is calling you to eat something else? I have eaten\nMy son, everyone',
#   'image': 'prop_meme_00374.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00375',
#   'text': 'Ready, kids?\nHey hey captain\nAnd the Prophet compensates Ali',
#   'image': 'prop_meme_00375.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00376',
#   'text': 'My daughter, all this sleep, get up and sit with us for a while!!\nI\nWhy do I take a nap for two days like this?',
#   'image': 'prop_meme_00376.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00399',
#   'text': 'If the wife knows that her husband’s salary has been reduced',
#   'image': 'prop_meme_00399.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00426',
#   'text': 'When you fear for the batch group\nBatch Jews:\nI finished the research, guys, very easy',
#   'image': 'prop_meme_00426.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00428',
#   'text': "China announces the death of the first case of Hantavirus\n\nWhat can I tell you, don't give it nuclear power and save us",
#   'image': 'prop_meme_00428.jpg',
#   'label': 'propagandistic'},
#  {'id': '00431',
#   'text': "*You*\nYou don't remember him anymore, loser\n Please don't call me a loser\nAre you upset with me, loser?\nOkay, you loser, you loser, you loser",
#   'image': 'prop_meme_00431.jpg',
#   'label': 'propagandistic'},
#  {'id': '00447',
#   'text': 'I was busy in my dream about you all last night\nhow did you see me ?\nUneducated',
#   'image': 'prop_meme_00447.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00460',
#   'text': 'Marriage, my brothers, is a failed project\n\nGot Engaged Today\n\nMy resemblance will remain, and your resemblance will be my life and your age',
#   'image': 'prop_meme_00460.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00472',
#   'text': 'North Korea announces its discovery of a cure for AIDS and Ebola',
#   'image': 'prop_meme_00472.jpg',
#   'label': 'propagandistic'},
#  {'id': '00479',
#   'text': '*your friend*\nYou are the one who told me that we must work hard to succeed and come out on top\n\n*You*\nYou talk to the teachers so we can start lessons, you idiot',
#   'image': 'prop_meme_00479.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00482',
#   'text': "When I'm sitting with people and I hear someone talking wrongly, I know what's right.\nIt is not my business\nIt is not my business\n It is not my business\nIt is not my business\n It is not my business\nIt is not my business\n It is not my business",
#   'image': 'prop_meme_00482.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00483',
#   'text': 'Everyone got engaged and got engaged in 2017\nExcept me and you, oh jinx, oh jinx',
#   'image': 'prop_meme_00483.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00490',
#   'text': 'You must forgive those who wronged you because we are in open days\nRespectful words and everything, but may God protect them',
#   'image': 'prop_meme_00490.jpg',
#   'label': 'propagandistic'},
#  {'id': '00491',
#   'text': 'China is fully recovering from Corona and warns its people against traveling to affected countries.',
#   'image': 'prop_meme_00491.jpg',
#   'label': 'propagandistic'},
#  {'id': '00499',
#   'text': "This cat's life is very miserable and he is poor and does not have a quarter of a tuna💔",
#   'image': 'prop_meme_00499.jpg',
#   'label': 'propagandistic'},
#  {'id': '00506',
#   'text': '| Is this Corona virus or not?\n I swear to God, my daughter, as long as you are sad about the whole world, then for sure women will be too😂😂',
#   'image': 'prop_meme_00506.jpg',
#   'label': 'propagandistic'},
#  {'id': '00541',
#   'text': 'Would you beat up your best friends for a million dollars??\nI:',
#   'image': 'prop_meme_00541.jpg',
#   'label': 'non_propagandistic'},
#  {'id': '00542',
#   'text': 'My children after you bullied half the planet',
#   'image': 'prop_meme_00542.jpg',
#   'label': 'propagandistic'},
#  {'id': '00573',
#   'text': 'When you come home late and your father tells you where you are now, dog:',
#   'image': 'prop_meme_00573.jpg',
#   'label': 'propagandistic'}]

# %% [markdown]
# #Submition Format
# "Subtask2b.txt", which means that the "Subtask2b.json" file should be renamed

# %%
dir = "Subtask2b.json"
data = trial_data

# %%
with open(dir, mode="wt", encoding = "utf-8") as f:
  json.dump(data,f,ensure_ascii=False, indent=4)
